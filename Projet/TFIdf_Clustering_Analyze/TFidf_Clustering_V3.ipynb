# %% [markdown]
# # Installing

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading https://files.pythonhosted.org/packages/30/f9/78dd244df932309299288a452d1c3524f6f7746f1813b8a8417952b1d9ce/pymongo-3.6.1-cp36-cp36m-manylinux1_x86_64.whl (378kB)
#     100% |████████████████████████████████| 389kB 9.1MB/s
# Installing collected packages: pymongo
# Successfully installed pymongo-3.6.1

# %% [markdown]
# # Importing

# %%
# Data preprocessing
import pandas as pd
import numpy as np
import datetime

# Stopwords, stemming, and tokenizing
import sys
import nltk
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from nltk.stem.snowball import SnowballStemmer
stemmerFR = SnowballStemmer("french")
stemmerEN = SnowballStemmer("english")
import re
from scipy import optimize

# MongoDB imports 
import pymongo
from pymongo import MongoClient

# Tf-idf and document similarity 
from sklearn.feature_extraction.text import TfidfVectorizer

# Clustering
from sklearn.cluster import KMeans
# Out:
# [nltk_data] Downloading package stopwords to /content/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /content/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Data Retrieval

# %% [markdown]
# **Connection to MongoDB**

# %%
client = MongoClient('mongodb://root:WebM2018Mse@dds-4xo14776d7c78aa41621-pub.mongodb.germany.rds.aliyuncs.com:3717/admin')
db = client.news

# %% [markdown]
# ** Le temps dataset**

# %%
COLLECTION_NAME = "allArticles"

articles_temps = list(db[COLLECTION_NAME].find({}))
dataframe = pd.DataFrame(articles_temps)

# %% [markdown]
# ** Convert ArticleDate to Datetime format and sort dataframe by date **

# %%
dataframe['articleDateFormatted'] = pd.to_datetime(dataframe['articleDate'], unit='ms')
dataframe = dataframe.sort_values(by=['articleDateFormatted'])

# %% [markdown]
# ** Remove entries where clearedHTML is empty **

# %%
dataframe = dataframe[dataframe['clearedHTML'] != ""].reset_index()
dataframe.head()
# Out:
#    level_0   index                       _id  articleDate  biMonth  \
# 0        0  115858  5ada135224ac6a250e026bdf        -3600  1970001
# 1        1  113174  5ad9f48a24ac6a117a12608e    939074400  1999019
# 2        2  130914  5ad9f54f24ac6a117a128812    939333600  1999019
# 3        3  113175  5ad9f48a24ac6a117a12608f    939420000  1999019
# 4        4  113176  5ad9f48a24ac6a117a126090    939592800  1999019
#
#                                         cleanContent  \
# 0  publi octobr 2017la polic berlinois annonc qu'...
# 1  telecom c'est samedi gen telecom sera aussi da...
# 2  dimanch jusqu janvier mus beyel riehen dan can...
# 3  c'est week end que telecom ouvr ses port des c...
# 4  gen est pour une semain mecqu l'industri des c...
#
#                                          clearedHTML   crawlDate  \
# 0  Publié le 03 octobre 2017La police berlinoise ...  1524241234
# 1  Telecom 99, c'est samedi à Genève. Telecom 200...  1524233354
# 2  Dès ce dimanche et jusqu’au 9 janvier, le musé...  1524233551
# 3  C'est ce week-end que Telecom 99 ouvre ses por...  1524233354
# 4  Genève est, pour une semaine, la Mecque de l'i...  1524233354
#
#                                                 html  \
# 0  <article>\n\t\t\t<div class="rts-module-infosp...
# 1  <div itemprop="articleBody">\n    <p class="le...
# 2  <div itemprop="articleBody">\n    <p class="le...
# 3  <div itemprop="articleBody">\n    <p class="le...
# 4  <div itemprop="articleBody">\n    <p class="le...
#
#                                  id     source     tags  test  \
# 0  cd233eda7c506f5b810fa10fc0839a92        rts  [Monde]  simo
# 1  e56272d2482f7cafda8e7c791b838bab  swissinfo       []   NaN
# 2  47faaca8b5e189b507ba93301c7e74f2  swissinfo       []   NaN
# 3  c112934bb26109ff5cc43ca3a0e473d0  swissinfo       []   NaN
# 4  4943a52f96385a12d62d65fc26bc54cd  swissinfo       []   NaN
#
#                                                title  \
# 0  Evacuation massive à Berlin à cause d'une bomb...
# 1       Telecom en 2003 comme en 1999 : c’est Genève
# 2  Le Musée Beyeler instaure un dialogue entre Cé...
# 3    Genève ouvre Telecom 99 : mobilisation générale
# 4  Telecom 99 : la grand-messe d’une industrie en...
#
#                                                  url    articleDateFormatted
# 0  https://www.rts.ch/info/monde/8968798-evacuati... 1969-12-31 23:59:56.400
# 1  https://www.swissinfo.ch/fre/telecom-en-2003-c... 1970-01-11 20:51:14.400
# 2  https://www.swissinfo.ch/fre/le-mus%C3%A9e-bey... 1970-01-11 20:55:33.600
# 3  https://www.swissinfo.ch/fre/gen%C3%A8ve-ouvre... 1970-01-11 20:57:00.000
# 4  https://www.swissinfo.ch/fre/telecom-99---la-g... 1970-01-11 20:59:52.800

# %% [markdown]
# ** Retrieval of the corpus **

# %%
db_corpus = client.corpus
pairs_got = db_corpus.allArticles.find_one({"id": "pairs2"})["pairs"]

# %% [markdown]
# # Pre-processing (Stopwords, stemming, and tokenizing)

# %% [markdown]
# ** New tokenize stem and cleaning method **

# %%
alphaOnly = lambda w: not w.replace('"', '').replace("'", '')\
          .replace(".", '').replace(",", '').isnumeric()

gt2 = lambda w: len(w) > 2

ppFilters = lambda w: alphaOnly(w) and gt2(w)

def clean_str(string):
  """Original taken
  from https://github.com/yoonkim/CNN_sentence/blob/master/process_data.py
  """
  string = re.sub(r"[^A-Za-z0-9()èéàÉÀêÊçÇ]", " ", string)
  string = re.sub(r"\'s", " \'s", string)
  string = re.sub(r"\'ve", " \'ve", string)
  string = re.sub(r"n\'t", " n\'t", string)
  string = re.sub(r"\'re", " \'re", string)
  string = re.sub(r"\'d", " \'d", string)
  string = re.sub(r"\'ll", " \'ll", string)
  string = re.sub(r",", " , ", string)
  string = re.sub(r"!", " ! ", string)
  string = re.sub(r"\(", " \( ", string)
  string = re.sub(r"\)", " \) ", string)
  string = re.sub(r"\?", " \? ", string)
  string = re.sub(r"\s{2,}", " ", string)
  return string.strip().lower()


def ppMaps(w):
  #w = clean_str(w)
  w = stemmerFR.stem(w)
  #w = stemmerEN.stem(w)
  return w

def preprocessing(tokens):
  tokens = list(filter(ppFilters, map(ppMaps, tokens)))
  return tokens

# Call `pro£cess_line` to use it.
def process_line(line):
  return preprocessing(word_tokenize(clean_str(line)))

# %% [markdown]
# ** Create the dataframe from two lists **

# %%
def vocabulary_frame_mongodb(totalvocab_tokenized, totalvocab_stemmed):     
  return pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)

# %% [markdown]
# # TFidf-vectorization

# %%
def tfidfVectorization(corpus, tokenize_func, stopwords_list, ngram_max=1, max_df=0.8, min_df=0.1):
  vectorizer = TfidfVectorizer(max_df=max_df, min_df=min_df, use_idf=True,
                               stop_words=stopwords_list, tokenizer=tokenize_func, 
                               ngram_range=(1,ngram_max))
   
  vectors_words_corpus = vectorizer.fit_transform(corpus) 
  terms = vectorizer.get_feature_names()
  return (vectors_words_corpus, terms)

# %% [markdown]
# # Clustering

# %%
def clustering(value_matrix, nb_clusters=5):
  # prevent kmeans from crashing if the number of clusters is too high
  nb_elements_in_matrix = len(value_matrix.toarray())
  if nb_elements_in_matrix < nb_clusters:
    nb_clusters = nb_elements_in_matrix
   
  # Makes the clustering andthe fitting
  kmeans_fitted = KMeans(n_clusters=nb_clusters)
  kmeans_fitted.fit(value_matrix)
  return kmeans_fitted

# %% [markdown]
# # Analyzing of the clustering

# %%
def findImportantWords(kmeans, vocab_frame, vocabulary_dataset, nb_words_for_clusters=6):
  order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1] 
  nb_clusters = len(order_centroids)
  words_all_cluster = []
  for i in range(nb_clusters):
    words_cluster = []
    for ind in order_centroids[i, :nb_words_for_clusters]: 
      word = vocab_frame.loc[vocabulary_dataset[ind].split(' ')].values.tolist()[0][0]      
      words_cluster.append(word)
    words_all_cluster.append(words_cluster)
  return words_all_cluster

# %% [markdown]
# # Final pipeline on a single subset

# %%
N_CLUSTERS = 5
FIELDNAME = 'clearedHTML'
TITLENAME = 'title'

# %%
unique_biMonth = dataframe['biMonth'].unique()
tuples_biMonth = [(unique_biMonth[i], unique_biMonth[i+1]) for i in range(len(unique_biMonth)-1)]

# %% [markdown]
# ** Work on a subset of the entire dataframe (one month) **

# %%
dataframe_subset = dataframe[dataframe['biMonth'].isin(tuples_biMonth[-1])]

# %% [markdown]
# ** Transform dataframe into two lists (title and content) **

# %%
corpus = np.asarray(dataframe_subset[FIELDNAME])

# %% [markdown]
# ** Stopwords, stemming, and tokenizing **

# %%
totalvocab_tokenized = list(pairs_got.keys())
totalvocab_stemmed = list(pairs_got.values())
vocab_frame = vocabulary_frame_mongodb(totalvocab_tokenized, totalvocab_stemmed)
stopwords_french = nltk.corpus.stopwords.words('french')

# %% [markdown]
# ** Tf-idf and document similarity **

# %%
(vectors_words_corpus, vocabulary_dataset) = tfidfVectorization(corpus, process_line, stopwords_french, 3)

# %% [markdown]
# ** K-means clustering **

# %%
num_clusters = N_CLUSTERS
kmeans_processing = clustering(vectors_words_corpus, 5)

# %% [markdown]
# ** Display of the results **

# %%
NB_WORDS_FOR_CLUSTER = 6
#sort cluster centers by proximity to centroid
order_centroids = kmeans_processing.cluster_centers_.argsort()[:, ::-1] 
nb_clusters = len(order_centroids)
for i in range(nb_clusters):
    print("Cluster %d words:" % i)
    for ind in order_centroids[i, :6]: #replace 6 with n words per cluster
        print(' %s,' % vocab_frame.loc[vocabulary_dataset[ind].split(' ')].values.tolist()[0][0], end='')
    print("")
# Out:
# Cluster 0 words:
#  francea, partiez, deux, milliona, premiers, selona,
# Cluster 1 words:
#  suissea, conseils, contrera, premiers, paye, troisa,
# Cluster 2 words:
#  femmea, hommasse, tout, mêmes, égales, êtres,
# Cluster 3 words:
#  américainea, etat, unis, etat, présidente, européenn,
# Cluster 4 words:
#  commissions, tout, mêmes, faits, grandirent, deux,

# %% [markdown]
# # Final pipeline generalized

# %%
N_CLUSTERS = 5
FIELDNAME = 'clearedHTML'
NB_WORDS_FOR_CLUSTER = 6
NGRAM_MAX = 1

# %% [markdown]
# ** Initialisation, make it when you change the dataframe **

# %%
unique_biMonth = dataframe['biMonth'].unique()
unique_biMonth.sort()
tuples_biMonth = [(unique_biMonth[i], unique_biMonth[i+1]) for i in range(len(unique_biMonth)-1)]

# %%
totalvocab_tokenized = list(pairs_got.keys())
totalvocab_stemmed = list(pairs_got.values())
vocab_frame = vocabulary_frame_mongodb(totalvocab_tokenized, totalvocab_stemmed)

# %%
stopwords_french = nltk.corpus.stopwords.words('french')

# %% [markdown]
# ** Make the tfidf-vectorization, clustering, finding of words on one tuple biMonth **

# %%
def topicAnalysisProcessingForMonth(dataframe, tuple_biMonth, vocab_frame, result_dict, nb_clusters=5, nb_words_by_cluster=5, ngram_max=2):
  dataframe_subset = dataframe[dataframe['biMonth'].isin(tuple_biMonth)]
  corpus = np.asarray(dataframe_subset[FIELDNAME])
  print("Tuple %s: Begin " % (tuple_biMonth,), end='')
  
  # TFidf-vectorization
  try:
    (vectors_words_corpus, vocabulary_dataset) = tfidfVectorization(corpus, process_line, stopwords_french, ngram_max, min_df=0.1) 
    print(", TFidf-vectorization done", end='')
  except ValueError:
    print(", After pruning, no terms remain. Try a lower min_df or a higher max_df !!!!!!")
    return
  
  # clustering 
  kmeans_processing = clustering(vectors_words_corpus, nb_clusters)
  print(", Clustering done", end='')
    
  # find most Important Words
  words_all_cluster = findImportantWords(kmeans_processing, vocab_frame, vocabulary_dataset, nb_words_by_cluster)
  print(", findImportantWords done")
  
  key = "%d-%d" % (tuple_biMonth)
  result_dict[key] = words_all_cluster

# %%
def printResults(result_dict):
  for key, words in result_dict.items():
    print("\n" + key + ":")
    for idx, val in enumerate(words):
      print("Cluster %d words:" % idx)
      print(val)

# %% [markdown]
# ** Processing on the entire dataset **

# %%
def topicAnalysisProcessing(limit=None):
  reversed_tuples_biMonth = list(reversed(tuples_biMonth))
  result_dict = {}
  for idx, tuple_biMonth in enumerate(reversed_tuples_biMonth):
    """if limit != None and idx >= limit:
      return result_dict"""
    topicAnalysisProcessingForMonth(dataframe, tuple_biMonth, vocab_frame, result_dict, N_CLUSTERS, NB_WORDS_FOR_CLUSTER, NGRAM_MAX)
  return result_dict

# %%
# %time result_dict = topicAnalysisProcessing()
# Out:
# Tuple (2018009, 2018010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2018008, 2018009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2018007, 2018008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2018006, 2018007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2018005, 2018006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2018004, 2018005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2018003, 2018004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2018002, 2018003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2018001, 2018002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017024, 2018001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017023, 2017024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017022, 2017023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017021, 2017022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017020, 2017021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017019, 2017020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017018, 2017019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017017, 2017018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017016, 2017017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017015, 2017016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017014, 2017015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017013, 2017014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017012, 2017013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017011, 2017012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017010, 2017011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017009, 2017010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017008, 2017009): Begin
# , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017007, 2017008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017006, 2017007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017005, 2017006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017004, 2017005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017003, 2017004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017002, 2017003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2017001, 2017002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016024, 2017001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016023, 2016024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016022, 2016023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016021, 2016022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016020, 2016021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016019, 2016020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016018, 2016019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016017, 2016018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016016, 2016017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016015, 2016016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016014, 2016015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016013, 2016014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016012, 2016013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016011, 2016012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016010, 2016011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016009, 2016010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016008, 2016009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016007, 2016008): Begin , TFidf-vectorization done
# , Clustering done, findImportantWords done
# Tuple (2016006, 2016007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016005, 2016006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016004, 2016005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016003, 2016004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016002, 2016003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2016001, 2016002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015024, 2016001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015023, 2015024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015022, 2015023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015021, 2015022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015020, 2015021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015019, 2015020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015018, 2015019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015017, 2015018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015016, 2015017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015015, 2015016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015014, 2015015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015013, 2015014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015012, 2015013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015011, 2015012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015010, 2015011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015009, 2015010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015008, 2015009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015007, 2015008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015006, 2015007): Begin , TFidf-vectorization done, Clustering done
# , findImportantWords done
# Tuple (2015005, 2015006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015004, 2015005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015003, 2015004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015002, 2015003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2015001, 2015002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014024, 2015001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014023, 2014024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014022, 2014023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014021, 2014022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014020, 2014021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014019, 2014020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014018, 2014019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014017, 2014018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014016, 2014017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014015, 2014016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014014, 2014015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014013, 2014014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014012, 2014013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014011, 2014012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014010, 2014011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014009, 2014010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014008, 2014009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014007, 2014008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014006, 2014007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014005, 2014006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014004, 2014005): Begin
# , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014003, 2014004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014002, 2014003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2014001, 2014002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013024, 2014001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013023, 2013024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013022, 2013023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013021, 2013022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013020, 2013021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013019, 2013020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013018, 2013019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013017, 2013018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013016, 2013017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013015, 2013016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013014, 2013015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013013, 2013014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013012, 2013013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013011, 2013012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013010, 2013011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013009, 2013010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013008, 2013009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013007, 2013008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013006, 2013007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013005, 2013006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013004, 2013005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013003, 2013004): Begin , TFidf-vectorization done
# , Clustering done, findImportantWords done
# Tuple (2013002, 2013003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2013001, 2013002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012024, 2013001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012023, 2012024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012022, 2012023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012021, 2012022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012020, 2012021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012019, 2012020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012018, 2012019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012017, 2012018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012016, 2012017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012015, 2012016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012014, 2012015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012013, 2012014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012012, 2012013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012011, 2012012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012010, 2012011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012009, 2012010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012008, 2012009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012007, 2012008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012006, 2012007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012005, 2012006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012004, 2012005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012003, 2012004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2012002, 2012003): Begin , TFidf-vectorization done, Clustering done
# , findImportantWords done
# Tuple (2012001, 2012002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011024, 2012001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011023, 2011024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011022, 2011023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011021, 2011022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011020, 2011021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011019, 2011020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011018, 2011019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011017, 2011018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011016, 2011017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011015, 2011016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011014, 2011015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011013, 2011014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011012, 2011013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011011, 2011012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011010, 2011011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011009, 2011010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011008, 2011009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011007, 2011008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011006, 2011007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011005, 2011006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011004, 2011005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011003, 2011004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011002, 2011003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2011001, 2011002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010024, 2011001): Begin
# , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010023, 2010024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010022, 2010023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010021, 2010022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010020, 2010021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010019, 2010020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010018, 2010019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010017, 2010018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010016, 2010017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010015, 2010016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010014, 2010015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010013, 2010014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010012, 2010013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010011, 2010012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010010, 2010011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010009, 2010010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010008, 2010009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010007, 2010008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010006, 2010007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010005, 2010006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010004, 2010005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010003, 2010004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010002, 2010003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2010001, 2010002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009024, 2010001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009023, 2009024): Begin , TFidf-vectorization done
# , Clustering done, findImportantWords done
# Tuple (2009022, 2009023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009021, 2009022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009020, 2009021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009019, 2009020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009018, 2009019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009017, 2009018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009016, 2009017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009015, 2009016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009014, 2009015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009013, 2009014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009012, 2009013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009011, 2009012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009010, 2009011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009009, 2009010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009008, 2009009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009007, 2009008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009006, 2009007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009005, 2009006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009004, 2009005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009003, 2009004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009002, 2009003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2009001, 2009002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008024, 2009001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008023, 2008024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008022, 2008023): Begin , TFidf-vectorization done, Clustering done
# , findImportantWords done
# Tuple (2008021, 2008022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008020, 2008021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008019, 2008020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008018, 2008019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008017, 2008018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008016, 2008017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008015, 2008016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008014, 2008015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008013, 2008014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008012, 2008013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008011, 2008012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008010, 2008011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008009, 2008010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008008, 2008009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008007, 2008008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008006, 2008007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008005, 2008006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008004, 2008005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008003, 2008004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008002, 2008003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2008001, 2008002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007024, 2008001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007023, 2007024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007022, 2007023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007021, 2007022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007020, 2007021): Begin
# , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007019, 2007020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007018, 2007019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007017, 2007018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007016, 2007017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007015, 2007016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007014, 2007015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007013, 2007014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007012, 2007013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007011, 2007012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007010, 2007011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007009, 2007010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007008, 2007009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007007, 2007008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007006, 2007007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007005, 2007006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007004, 2007005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007003, 2007004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007002, 2007003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2007001, 2007002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006024, 2007001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006023, 2006024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006022, 2006023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006021, 2006022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006020, 2006021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006019, 2006020): Begin , TFidf-vectorization done
# , Clustering done, findImportantWords done
# Tuple (2006018, 2006019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006017, 2006018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006016, 2006017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006015, 2006016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006014, 2006015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006013, 2006014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006012, 2006013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006011, 2006012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006010, 2006011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006009, 2006010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006008, 2006009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006007, 2006008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006006, 2006007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006005, 2006006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006004, 2006005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006003, 2006004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006002, 2006003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2006001, 2006002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005024, 2006001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005023, 2005024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005022, 2005023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005021, 2005022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005020, 2005021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005019, 2005020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005018, 2005019): Begin , TFidf-vectorization done, Clustering done
# , findImportantWords done
# Tuple (2005017, 2005018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005016, 2005017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005015, 2005016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005014, 2005015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005013, 2005014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005012, 2005013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005011, 2005012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005010, 2005011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005009, 2005010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005008, 2005009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005007, 2005008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005006, 2005007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005005, 2005006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005004, 2005005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005003, 2005004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005002, 2005003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2005001, 2005002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004024, 2005001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004023, 2004024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004022, 2004023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004021, 2004022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004020, 2004021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004019, 2004020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004018, 2004019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004017, 2004018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004016, 2004017): Begin
# , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004015, 2004016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004014, 2004015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004013, 2004014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004012, 2004013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004011, 2004012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004010, 2004011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004009, 2004010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004008, 2004009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004007, 2004008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004006, 2004007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004005, 2004006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004004, 2004005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004003, 2004004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004002, 2004003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2004001, 2004002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003024, 2004001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003023, 2003024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003022, 2003023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003021, 2003022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003020, 2003021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003019, 2003020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003018, 2003019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003017, 2003018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003016, 2003017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003015, 2003016): Begin , TFidf-vectorization done, Clustering done
# , findImportantWords done
# Tuple (2003014, 2003015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003013, 2003014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003012, 2003013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003011, 2003012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003010, 2003011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003009, 2003010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003008, 2003009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003007, 2003008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003006, 2003007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003005, 2003006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003004, 2003005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003003, 2003004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003002, 2003003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2003001, 2003002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002024, 2003001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002023, 2002024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002022, 2002023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002021, 2002022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002020, 2002021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002019, 2002020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002018, 2002019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002017, 2002018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002016, 2002017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002015, 2002016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002014, 2002015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002013, 2002014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002012, 2002013): Begin
# , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002011, 2002012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002010, 2002011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002009, 2002010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002008, 2002009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002007, 2002008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002006, 2002007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002005, 2002006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002004, 2002005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002003, 2002004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002002, 2002003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2002001, 2002002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001024, 2002001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001023, 2001024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001022, 2001023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001021, 2001022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001020, 2001021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001019, 2001020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001018, 2001019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001017, 2001018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001016, 2001017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001015, 2001016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001014, 2001015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001013, 2001014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001012, 2001013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001011, 2001012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001010, 2001011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001009, 2001010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001008, 2001009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001007, 2001008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001006, 2001007): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001005, 2001006): Begin
# , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001004, 2001005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001003, 2001004): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001002, 2001003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2001001, 2001002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000024, 2001001): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000023, 2000024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000022, 2000023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000021, 2000022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000020, 2000021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000019, 2000020): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000018, 2000019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000017, 2000018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000016, 2000017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000015, 2000016): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000014, 2000015): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000013, 2000014): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000011, 2000013): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000006, 2000011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000005, 2000006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000003, 2000005): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (2000002, 2000003): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999024, 2000002): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999023, 1999024): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999022, 1999023): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999021, 1999022): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999019, 1999021): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999018, 1999019): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999017, 1999018): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999012, 1999017): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999010, 1999012): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1999006, 1999010): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1998011, 1999006): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1998009, 1998011): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1998008, 1998009): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# Tuple (1970001, 1998008): Begin , TFidf-vectorization done, Clustering done, findImportantWords done
# CPU times: user 1h 18min 44s, sys: 3.2 s, total: 1h 18min 47s
# Wall time: 1h 18min 57s

# %% [markdown]
# ** Results of entire dataset **

# %%
printResults(result_dict)
# Out:
# 2018009-2018010:
# Cluster 0 words:
# ['suissea', 'francea', 'selona', 'deux', 'paye', 'êtres']
# Cluster 1 words:
# ['femmea', 'hommasse', 'filmait', 'égales', 'pétasse', 'mêmes']
# Cluster 2 words:
# ['conseils', 'etat', 'pierre', 'genevoises', 'fédérales', 'genèvea']
# Cluster 3 words:
# ['dollari', 'américainea', 'trumpés', 'etat', 'accordait', 'unis']
# Cluster 4 words:
# ['commissions', 'tout', 'grandirent', 'deux', 'filmait', 'anné']
#
# 2018008-2018009:
# Cluster 0 words:
# ['policées', 'deux', 'nxp', 'final', 'minute', 'après']
# Cluster 1 words:
# ['femmea', 'hommasse', 'plusa', 'auss', 'cétait', 'égales']
# Cluster 2 words:
# ['plusa', 'tout', 'cétait', 'commissions', 'auss', 'grandirent']
# Cluster 3 words:
# ['suissea', 'plusa', 'francea', 'milliona', 'cétait', 'entreprises']
# Cluster 4 words:
# ['présidente', 'etat', 'nordé', 'américainea', 'accordait', 'ministre']
#
# 2018007-2018008:
# Cluster 0 words:
# ['nxp', 'deux', 'plusa', 'cétait', 'minute', 'faits']
# Cluster 1 words:
# ['présidente', 'américainea', 'nordé', 'etat', 'suda', 'contrera']
# Cluster 2 words:
# ['match', 'final', 'buté', 'saisons', 'pointe', 'équipera']
# Cluster 3 words:
# ['plusa', 'tout', 'cétait', 'auss', 'commissions', 'mêmes']
# Cluster 4 words:
# ['suissea', 'francea', 'plusa', 'milliona', 'conseils', 'entreprises']
#
# 2018006-2018007:
# Cluster 0 words:
# ['cétait', 'plusa', 'avoir', 'selona', 'enquêter', 'faits']
# Cluster 1 words:
# ['plusa', 'tout', 'cétait', 'commissions', 'mêmes', 'auss']
# Cluster 2 words:
# ['match', 'final', 'saisons', 'buté', 'pointe', 'victoire']
# Cluster 3 words:
# ['russa', 'contrera', 'attaquaient', 'présidente', 'etat', 'américainea']
# Cluster 4 words:
# ['francea', 'suissea', 'plusa', 'conseils', 'milliona', 'etat']
#
# 2018005-2018006:
# Cluster 0 words:
# ['plusa', 'suissea', 'tout', 'cétait', 'auss', 'commissions']
# Cluster 1 words:
# ['match', 'saisons', 'final', 'pointe', 'buté', 'joueur']
# Cluster 2 words:
# ['russa', 'affairée', 'ministre', 'selona', 'annonceront', 'déclaratives']
# Cluster 3 words:
# ['trumpés', 'donald', 'américainea', 'présidente', 'etat', 'unis']
# Cluster 4 words:
# ['francea', 'selona', 'cétait', 'deux', 'plusa', 'nxp']
#
# 2018004-2018005:
# Cluster 0 words:
# ['match', 'final', 'équipera', 'pointe', 'nxp', 'suissea']
# Cluster 1 words:
# ['américainea', 'plusa', 'cétait', 'faits', 'selona', 'deux']
# Cluster 2 words:
# ['plusa', 'tout', 'commissions', 'auss', 'cétait', 'mêmes']
# Cluster 3 words:
# ['conseils', 'fédérales', 'suissea', 'milliona', 'francea', 'entreprises']
# Cluster 4 words:
# ['russa', 'olympe', 'selona', 'contrera', 'dimanchea', 'annonceront']
#
# 2018003-2018004:
# Cluster 0 words:
# ['médailles', 'olympe', 'ski', 'suissea', 'jeuxa', 'pyeongchang']
# Cluster 1 words:
# ['russa', 'nordé', 'suda', 'olympe', 'core', 'jeuxa']
# Cluster 2 words:
# ['match', 'final', 'pointe', 'équipera', 'buté', 'contrera']
# Cluster 3 words:
# ['plusa', 'faits', 'cétait', 'tout', 'commissions', 'femmea']
# Cluster 4 words:
# ['plusa', 'conseils', 'suissea', 'fédérales', 'auss', 'milliona']
#
# 2018002-2018003:
# Cluster 0 words:
# ['match', 'final', 'nxp', 'premiers', 'deux', 'saisons']
# Cluster 1 words:
# ['olympe', 'jeuxa', 'nordé', 'suda', 'pyeongchang', 'russa']
# Cluster 2 words:
# ['cétait', 'selona', 'faits', 'contrera', 'plusa', 'depuis']
# Cluster 3 words:
# ['trumpés', 'donald', 'présidente', 'américainea', 'etat', 'unis']
# Cluster 4 words:
# ['plusa', 'suissea', 'auss', 'commissions', 'cétait', 'tout']
#
# 2018001-2018002:
# Cluster 0 words:
# ['plusa', 'francea', 'nordé', 'selona', 'milliona', 'présidente']
# Cluster 1 words:
# ['trumpés', 'donald', 'présidente', 'américainea', 'etat', 'unis']
# Cluster 2 words:
# ['suissea', 'fédérales', 'plusa', 'conseils', 'series', 'partiez']
# Cluster 3 words:
# ['plusa', 'tout', 'cétait', 'femmea', 'the', 'commissions']
# Cluster 4 words:
# ['match', 'final', 'nxp', 'saisons', 'pointe', 'premiers']
#
# 2017024-2018001:
# Cluster 0 words:
# ['trumpés', 'donald', 'américainea', 'présidente', 'etat', 'unis']
# Cluster 1 words:
# ['nordé', 'person', 'selona', 'suda', 'mortes', 'deux']
# Cluster 2 words:
# ['suissea', 'francea', 'plusa', 'milliona', 'présidente', 'partiez']
# Cluster 3 words:
# ['plusa', 'tout', 'cétait', 'commissions', 'series', 'auss']
# Cluster 4 words:
# ['match', 'pointe', 'buté', 'saisons', 'final', 'premiers']
#
# 2017023-2017024:
# Cluster 0 words:
# ['nordé', 'russa', 'plusa', 'paye', 'suda', 'mortes']
# Cluster 1 words:
# ['match', 'buté', 'saisons', 'final', 'couperai', 'pointe']
# Cluster 2 words:
# ['plusa', 'tout', 'commissions', 'cétait', 'mêmes', 'auss']
# Cluster 3 words:
# ['francea', 'suissea', 'plusa', 'nxp', 'cétait', 'milliona']
# Cluster 4 words:
# ['trumpés', 'etat', 'donald', 'américainea', 'unis', 'présidente']
#
# 2017022-2017023:
# Cluster 0 words:
# ['trumpés', 'etat', 'américainea', 'nordé', 'unis', 'donald']
# Cluster 1 words:
# ['russa', 'présidente', 'etat', 'grouper', 'enquêter', 'américainea']
# Cluster 2 words:
# ['suissea', 'conseils', 'présidente', 'plusa', 'paye', 'francea']
# Cluster 3 words:
# ['match', 'saisons', 'buté', 'final', 'équipera', 'premiers']
# Cluster 4 words:
# ['plusa', 'tout', 'cétait', 'femmea', 'faits', 'commissions']
#
# 2017021-2017022:
# Cluster 0 words:
# ['sexuel', 'femmea', 'accusions', 'avoir', 'hommasse', 'affairée']
# Cluster 1 words:
# ['match', 'buté', 'final', 'saisons', 'joueur', 'équipera']
# Cluster 2 words:
# ['plusa', 'tout', 'cétait', 'deux', 'auss', 'commissions']
# Cluster 3 words:
# ['suissea', 'paye', 'conseils', 'plusa', 'francea', 'gouvernait']
# Cluster 4 words:
# ['trumpés', 'américainea', 'russa', 'nordé', 'présidente', 'etat']
#
# 2017020-2017021:
# Cluster 0 words:
# ['plusa', 'suissea', 'cétait', 'francea', 'tout', 'commissions']
# Cluster 1 words:
# ['match', 'buté', 'saisons', 'final', 'joueur', 'équipera']
# Cluster 2 words:
# ['trumpés', 'américainea', 'donald', 'présidente', 'nordé', 'russa']
# Cluster 3 words:
# ['sexuel', 'femmea', 'accusions', 'avoir', 'faits', 'hommasse']
# Cluster 4 words:
# ['gouvernait', 'conseils', 'etat', 'fédérales', 'présidente', 'ministre']
#
# 2017019-2017020:
# Cluster 0 words:
# ['match', 'buté', 'final', 'saisons', 'pointe', 'fac']
# Cluster 1 words:
# ['femmea', 'accusions', 'avoir', 'new', 'faits', 'révélait']
# Cluster 2 words:
# ['gouvernait', 'présidente', 'déclaratives', 'plusa', 'régions', 'etat']
# Cluster 3 words:
# ['plusa', 'suissea', 'francea', 'cétait', 'auss', 'milliona']
# Cluster 4 words:
# ['trumpés', 'américainea', 'donald', 'etat', 'présidente', 'unis']
#
# 2017018-2017019:
# Cluster 0 words:
# ['match', 'buté', 'final', 'fac', 'saisons', 'joueur']
# Cluster 1 words:
# ['plusa', 'faits', 'cétait', 'femmea', 'êtres', 'avoir']
# Cluster 2 words:
# ['trumpés', 'américainea', 'donald', 'nordé', 'etat', 'présidente']
# Cluster 3 words:
# ['suissea', 'fédérales', 'plusa', 'conseils', 'francea', 'européenn']
# Cluster 4 words:
# ['policées', 'gouvernait', 'plusa', 'déclaratives', 'selona', 'régions']
#
# 2017017-2017018:
# Cluster 0 words:
# ['plusa', 'cétait', 'francea', 'suissea', 'nxp', 'commissions']
# Cluster 1 words:
# ['match', 'final', 'joueur', 'saisons', 'buté', 'fac']
# Cluster 2 words:
# ['fédérales', 'conseils', 'suissea', 'plusa', 'partiez', 'projeta']
# Cluster 3 words:
# ['nordé', 'trumpés', 'américainea', 'donald', 'etat', 'unis']
# Cluster 4 words:
# ['plusa', 'paye', 'partiez', 'etat', 'selona', 'person']
#
# 2017016-2017017:
# Cluster 0 words:
# ['trumpés', 'nordé', 'américainea', 'donald', 'présidente', 'etat']
# Cluster 1 words:
# ['suissea', 'fédérales', 'conseils', 'plusa', 'francea', 'projeta']
# Cluster 2 words:
# ['plusa', 'cétait', 'commissions', 'francea', 'tout', 'nxp']
# Cluster 3 words:
# ['policées', 'person', 'mortes', 'blesser', 'attaquaient', 'selona']
# Cluster 4 words:
# ['match', 'final', 'saisons', 'joueur', 'équipera', 'fac']
#
# 2017015-2017016:
# Cluster 0 words:
# ['policées', 'blesser', 'person', 'attaquaient', 'mortes', 'hommasse']
# Cluster 1 words:
# ['suissea', 'conseils', 'fédérales', 'plusa', 'auss', 'partiez']
# Cluster 2 words:
# ['plusa', 'milliona', 'cétait', 'francea', 'commissions', 'tout']
# Cluster 3 words:
# ['trumpés', 'américainea', 'présidente', 'donald', 'etat', 'unis']
# Cluster 4 words:
# ['match', 'final', 'clubs', 'saisons', 'joueur', 'après']
#
# 2017014-2017015:
# Cluster 0 words:
# ['fédérales', 'conseils', 'suissea', 'nationales', 'partiez', 'présidente']
# Cluster 1 words:
# ['final', 'match', 'saisons', 'premiers', 'après', 'dernier']
# Cluster 2 words:
# ['selona', 'paye', 'présidente', 'nordé', 'etat', 'contrera']
# Cluster 3 words:
# ['plusa', 'milliona', 'cétait', 'tout', 'anné', 'suissea']
# Cluster 4 words:
# ['trumpés', 'donald', 'russa', 'américainea', 'présidente', 'etat']
#
# 2017013-2017014:
# Cluster 0 words:
# ['présidente', 'etat', 'paye', 'gouvernait', 'ministre', 'conseils']
# Cluster 1 words:
# ['villas', 'nordé', 'selona', 'nxp', 'mortes', 'deux']
# Cluster 2 words:
# ['trumpés', 'donald', 'russa', 'présidente', 'américainea', 'etat']
# Cluster 3 words:
# ['final', 'match', 'tourer', 'premiers', 'fac', 'après']
# Cluster 4 words:
# ['plusa', 'suissea', 'francea', 'tout', 'cétait', 'commissions']
#
# 2017012-2017013:
# Cluster 0 words:
# ['chez', 'suissea', 'permettre', 'localités', 'problème', 'différentea']
# Cluster 1 words:
# ['final', 'tourer', 'premiers', 'fac', 'nxp', 'dernier']
# Cluster 2 words:
# ['plusa', 'francea', 'suissea', 'selona', 'cétait', 'présidente']
# Cluster 3 words:
# ['plusa', 'tout', 'femmea', 'êtres', 'faits', 'cétait']
# Cluster 4 words:
# ['trumpés', 'donald', 'américainea', 'russa', 'présidente', 'etat']
#
# 2017011-2017012:
# Cluster 0 words:
# ['chez', 'suissea', 'problème', 'permettre', 'localités', 'différentea']
# Cluster 1 words:
# ['trumpés', 'donald', 'américainea', 'présidente', 'etat', 'unis']
# Cluster 2 words:
# ['plusa', 'cétait', 'faits', 'deux', 'autre', 'tout']
# Cluster 3 words:
# ['final', 'match', 'premiers', 'plusa', 'tourer', 'équipera']
# Cluster 4 words:
# ['suissea', 'conseils', 'francea', 'fédérales', 'partiez', 'plusa']
#
# 2017010-2017011:
# Cluster 0 words:
# ['trumpés', 'donald', 'présidente', 'américainea', 'russa', 'etat']
# Cluster 1 words:
# ['suissea', 'francea', 'conseils', 'fédérales', 'plusa', 'partiez']
# Cluster 2 words:
# ['plusa', 'tout', 'faits', 'cétait', 'grandirent', 'commissions']
# Cluster 3 words:
# ['attentats', 'policées', 'nordé', 'person', 'attaquaient', 'terroriste']
# Cluster 4 words:
# ['final', 'match', 'saisons', 'victoire', 'championne', 'joueur']
#
# 2017009-2017010:
# Cluster 0 words:
# ['macron', 'emmanuèle', 'francea', 'candidat', 'présidente', 'ministre']
# Cluster 1 words:
# ['suissea', 'plusa', 'francea', 'milliona', 'fédérales', 'cétait']
# Cluster 2 words:
# ['final', 'match', 'saisons', 'victoire', 'buté', 'fac']
# Cluster 3 words:
# ['plusa', 'faits', 'cétait', 'après', 'tout', 'grandirent']
# Cluster 4 words:
# ['trumpés', 'donald', 'présidente', 'américainea', 'russa', 'etat']
#
# 2017008-2017009:
# Cluster 0 words:
# ['macron', 'penna', 'emmanuèle', 'candidat', 'francea', 'marini']
# Cluster 1 words:
# ['plusa', 'suissea', 'cétait', 'francea', 'tout', 'milliona']
# Cluster 2 words:
# ['trumpés', 'donald', 'américainea', 'présidente', 'maisona', 'etat']
# Cluster 3 words:
# ['nordé', 'etat', 'selona', 'présidente', 'paye', 'mortes']
# Cluster 4 words:
# ['match', 'final', 'buté', 'saisons', 'pointe', 'deux']
#
# 2017007-2017008:
# Cluster 0 words:
# ['match', 'final', 'saisons', 'buté', 'joueur', 'pointe']
# Cluster 1 words:
# ['trumpés', 'américainea', 'donald', 'nordé', 'présidente', 'etat']
# Cluster 2 words:
# ['penna', 'candidat', 'macron', 'francea', 'marini', 'tourer']
# Cluster 3 words:
# ['selona', 'person', 'attaquaient', 'après', 'contrera', 'avril']
# Cluster 4 words:
# ['plusa', 'suissea', 'francea', 'cétait', 'auss', 'tout']
#
# 2017006-2017007:
# Cluster 0 words:
# ['candidat', 'françoise', 'présidentiela', 'francea', 'socialité', 'droitea']
# Cluster 1 words:
# ['trumpés', 'donald', 'américainea', 'etat', 'présidente', 'unis']
# Cluster 2 words:
# ['plusa', 'faits', 'cétait', 'après', 'êtres', 'person']
# Cluster 3 words:
# ['suissea', 'plusa', 'francea', 'milliona', 'anné', 'cétait']
# Cluster 4 words:
# ['match', 'final', 'saisons', 'buté', 'pointe', 'victoire']
#
# 2017005-2017006:
# Cluster 0 words:
# ['trumpés', 'donald', 'américainea', 'etat', 'unis', 'présidente']
# Cluster 1 words:
# ['match', 'final', 'saisons', 'pointe', 'victoire', 'buté']
# Cluster 2 words:
# ['plusa', 'suissea', 'francea', 'cétait', 'milliona', 'auss']
# Cluster 3 words:
# ['françoise', 'candidat', 'présidentiela', 'droitea', 'francea', 'socialité']
# Cluster 4 words:
# ['policées', 'paye', 'européenn', 'selona', 'après', 'plusa']
#
# 2017004-2017005:
# Cluster 0 words:
# ['plusa', 'suissea', 'francea', 'cétait', 'milliona', 'conseils']
# Cluster 1 words:
# ['match', 'final', 'saisons', 'pointe', 'buté', 'minute']
# Cluster 2 words:
# ['policées', 'européenn', 'paye', 'contrera', 'selona', 'afp']
# Cluster 3 words:
# ['candidat', 'droitea', 'présidentiela', 'francea', 'tourer', 'campagne']
# Cluster 4 words:
# ['trumpés', 'donald', 'américainea', 'etat', 'présidente', 'unis']
#
# 2017003-2017004:
# Cluster 0 words:
# ['match', 'pointe', 'final', 'buté', 'saisons', 'victoire']
# Cluster 1 words:
# ['trumpés', 'donald', 'américainea', 'présidente', 'etat', 'unis']
# Cluster 2 words:
# ['plusa', 'tout', 'cétait', 'monde', 'series', 'faits']
# Cluster 3 words:
# ['francea', 'selona', 'nordé', 'européenn', 'plusa', 'contrera']
# Cluster 4 words:
# ['suissea', 'conseils', 'francea', 'fédérales', 'plusa', 'milliona']
#
# 2017002-2017003:
# Cluster 0 words:
# ['candidat', 'droitea', 'ministre', 'francea', 'présidentiela', 'socialité']
# Cluster 1 words:
# ['plusa', 'cétait', 'milliona', 'faits', 'francea', 'grouper']
# Cluster 2 words:
# ['trumpés', 'donald', 'américainea', 'présidente', 'etat', 'unis']
# Cluster 3 words:
# ['match', 'final', 'pointe', 'premiers', 'victoire', 'deux']
# Cluster 4 words:
# ['suissea', 'fédérales', 'plusa', 'conseils', 'entreprises', 'projeta']
#
# 2017001-2017002:
# Cluster 0 words:
# ['plusa', 'cétait', 'milliona', 'francea', 'series', 'anné']
# Cluster 1 words:
# ['match', 'final', 'pointe', 'premiers', 'victoire', 'fac']
# Cluster 2 words:
# ['ministre', 'deux', 'européenn', 'plusa', 'selona', 'grouper']
# Cluster 3 words:
# ['trumpés', 'donald', 'présidente', 'américainea', 'unis', 'etat']
# Cluster 4 words:
# ['suissea', 'fédérales', 'économiquement', 'plusa', 'entreprises', 'présidente']
#
# 2016024-2017001:
# Cluster 0 words:
# ['suissea', 'fédérales', 'plusa', 'économiquement', 'francea', 'conseils']
# Cluster 1 words:
# ['trumpés', 'donald', 'présidente', 'américainea', 'etat', 'unis']
# Cluster 2 words:
# ['russa', 'trumpés', 'américainea', 'présidente', 'donald', 'etat']
# Cluster 3 words:
# ['match', 'pointe', 'saisons', 'premiers', 'buté', 'final']
# Cluster 4 words:
# ['plusa', 'cétait', 'faits', 'selona', 'après', 'deux']
#
# 2016023-2016024:
# Cluster 0 words:
# ['trumpés', 'donald', 'présidente', 'américainea', 'etat', 'unis']
# Cluster 1 words:
# ['suissea', 'francea', 'plusa', 'conseils', 'milliona', 'ministre']
# Cluster 2 words:
# ['russa', 'américainea', 'présidente', 'selona', 'villas', 'etat']
# Cluster 3 words:
# ['pointe', 'saisons', 'buté', 'victoire', 'final', 'couperai']
# Cluster 4 words:
# ['plusa', 'après', 'policées', 'selona', 'cétait', 'faits']
#
# 2016022-2016023:
# Cluster 0 words:
# ['suissea', 'conseils', 'fédérales', 'francea', 'milliona', 'plusa']
# Cluster 1 words:
# ['présidente', 'ministre', 'gouvernait', 'politiste', 'européenn', 'premiers']
# Cluster 2 words:
# ['saisons', 'pointe', 'buté', 'final', 'victoire', 'couperai']
# Cluster 3 words:
# ['plusa', 'selona', 'cétait', 'faits', 'après', 'contrera']
# Cluster 4 words:
# ['trumpés', 'donald', 'présidente', 'américainea', 'etat', 'unis']
#
# 2016021-2016022:
# Cluster 0 words:
# ['plusa', 'cétait', 'francea', 'deux', 'faits', 'après']
# Cluster 1 words:
# ['match', 'final', 'pointe', 'fac', 'deux', 'premiers']
# Cluster 2 words:
# ['suissea', 'fédérales', 'plusa', 'conseils', 'francea', 'entreprises']
# Cluster 3 words:
# ['présidente', 'ministre', 'plusa', 'etat', 'paye', 'droitea']
# Cluster 4 words:
# ['trumpés', 'donald', 'américainea', 'présidente', 'etat', 'clinton']
#
# 2016020-2016021:
# Cluster 0 words:
# ['match', 'final', 'pointe', 'fac', 'premiers', 'deux']
# Cluster 1 words:
# ['villas', 'etat', 'força', 'présidente', 'selona', 'nordé']
# Cluster 2 words:
# ['trumpés', 'donald', 'clinton', 'hillary', 'américainea', 'présidente']
# Cluster 3 words:
# ['suissea', 'milliard', 'plusa', 'francea', 'milliona', 'fédérales']
# Cluster 4 words:
# ['plusa', 'cétait', 'tout', 'faits', 'deux', 'depuis']
#
# 2016019-2016020:
# Cluster 0 words:
# ['etat', 'paye', 'plusa', 'selona', 'villas', 'présidente']
# Cluster 1 words:
# ['candidat', 'femmea', 'campagne', 'présidente', 'américainea', 'plusa']
# Cluster 2 words:
# ['suissea', 'fédérales', 'plusa', 'francea', 'conseils', 'entreprises']
# Cluster 3 words:
# ['match', 'saisons', 'minute', 'pointe', 'final', 'premiers']
# Cluster 4 words:
# ['plusa', 'cétait', 'tout', 'faits', 'deux', 'êtres']
#
# 2016018-2016019:
# Cluster 0 words:
# ['candidat', 'présidente', 'campagne', 'anciennement', 'américainea', 'etat']
# Cluster 1 words:
# ['plusa', 'cétait', 'tout', 'faits', 'auss', 'êtres']
# Cluster 2 words:
# ['match', 'saisons', 'équipera', 'buté', 'pointe', 'premiers']
# Cluster 3 words:
# ['suissea', 'conseils', 'fédérales', 'francea', 'plusa', 'milliona']
# Cluster 4 words:
# ['etat', 'selona', 'paye', 'plusa', 'américainea', 'mortes']
#
# 2016017-2016018:
# Cluster 0 words:
# ['candidat', 'présidente', 'américainea', 'campagne', 'etat', 'anciennement']
# Cluster 1 words:
# ['match', 'final', 'buté', 'équipera', 'contrera', 'fac']
# Cluster 2 words:
# ['etat', 'selona', 'américainea', 'paye', 'grouper', 'plusa']
# Cluster 3 words:
# ['plusa', 'tout', 'cétait', 'auss', 'series', 'deux']
# Cluster 4 words:
# ['suissea', 'conseils', 'fédérales', 'plusa', 'francea', 'projeta']
#
# 2016016-2016017:
# Cluster 0 words:
# ['final', 'plusa', 'deux', 'après', 'équipera', 'minute']
# Cluster 1 words:
# ['après', 'plusa', 'deux', 'cétait', 'avoir', 'présidente']
# Cluster 2 words:
# ['suissea', 'fédérales', 'conseils', 'économiquement', 'plusa', 'nationales']
# Cluster 3 words:
# ['etat', 'américainea', 'unis', 'grouper', 'paye', 'présidente']
# Cluster 4 words:
# ['plusa', 'milliona', 'auss', 'francea', 'cétait', 'utilisèrent']
#
# 2016015-2016016:
# Cluster 0 words:
# ['hommasse', 'person', 'après', 'deux', 'selona', 'francea']
# Cluster 1 words:
# ['suissea', 'plusa', 'fédérales', 'conseils', 'êtres', 'économiquement']
# Cluster 2 words:
# ['plusa', 'tout', 'cétait', 'series', 'faits', 'faires']
# Cluster 3 words:
# ['milliona', 'francea', 'plusa', 'anné', 'marchea', 'grouper']
# Cluster 4 words:
# ['etat', 'américainea', 'unis', 'présidente', 'grouper', 'contrera']
#
# 2016014-2016015:
# Cluster 0 words:
# ['démocrate', 'américainea', 'présidente', 'etat', 'partiez', 'unis']
# Cluster 1 words:
# ['juillettistes', 'come', 'grandirent', 'plusa', 'vendredis', 'jami']
# Cluster 2 words:
# ['plusa', 'suissea', 'cétait', 'tout', 'francea', 'series']
# Cluster 3 words:
# ['turquie', 'etat', 'couperai', 'présidente', 'arméea', 'ministre']
# Cluster 4 words:
# ['policées', 'attentats', 'person', 'hommasse', 'selona', 'attaquaient']
#
# 2016013-2016014:
# Cluster 0 words:
# ['etat', 'présidente', 'américainea', 'européenn', 'unis', 'paye']
# Cluster 1 words:
# ['final', 'tourer', 'premiers', 'deux', 'fac', 'francea']
# Cluster 2 words:
# ['plusa', 'suissea', 'cétait', 'tout', 'milliona', 'commissions']
# Cluster 3 words:
# ['juillettistes', 'come', 'titrant', 'plusa', 'grandirent', 'américainea']
# Cluster 4 words:
# ['attentats', 'policées', 'person', 'policia', 'hommasse', 'attaquaient']
#
# 2016012-2016013:
# Cluster 0 words:
# ['final', 'tourer', 'titrant', 'premiers', 'deux', 'fac']
# Cluster 1 words:
# ['plusa', 'tout', 'cétait', 'faits', 'auss', 'commissions']
# Cluster 2 words:
# ['européenn', 'brexit', 'britanniques', 'royaumes', 'unie', 'unionistes']
# Cluster 3 words:
# ['policées', 'etat', 'américainea', 'contrera', 'selona', 'juillettistes']
# Cluster 4 words:
# ['suissea', 'fédérales', 'plusa', 'conseils', 'francea', 'êtres']
#
# 2016011-2016012:
# Cluster 0 words:
# ['etat', 'policées', 'américainea', 'selona', 'depuis', 'hommasse']
# Cluster 1 words:
# ['suissea', 'plusa', 'fédérales', 'conseils', 'francea', 'entreprises']
# Cluster 2 words:
# ['final', 'titrant', 'jami', 'fac', 'premiers', 'mondialistes']
# Cluster 3 words:
# ['plusa', 'tout', 'cétait', 'faits', 'jeune', 'series']
# Cluster 4 words:
# ['européenn', 'brexit', 'britanniques', 'royaumes', 'unie', 'unionistes']
#
# 2016010-2016011:
# Cluster 0 words:
# ['plusa', 'tout', 'faits', 'cétait', 'series', 'commissions']
# Cluster 1 words:
# ['etat', 'policées', 'selona', 'afp', 'après', 'person']
# Cluster 2 words:
# ['francea', 'milliona', 'conseils', 'plusa', 'fédérales', 'entreprises']
# Cluster 3 words:
# ['suissea', 'plusa', 'paye', 'auss', 'cétait', 'person']
# Cluster 4 words:
# ['final', 'match', 'premiers', 'fac', 'deux', 'équipera']
#
# 2016009-2016010:
# Cluster 0 words:
# ['suissea', 'fédérales', 'conseils', 'plusa', 'francea', 'cétait']
# Cluster 1 words:
# ['final', 'match', 'pointe', 'fac', 'premiers', 'deux']
# Cluster 2 words:
# ['villas', 'nordé', 'person', 'selona', 'plusa', 'mortes']
# Cluster 3 words:
# ['plusa', 'tout', 'faits', 'cétait', 'faires', 'commissions']
# Cluster 4 words:
# ['francea', 'présidente', 'milliona', 'américainea', 'plusa', 'etat']
#
# 2016008-2016009:
# Cluster 0 words:
# ['plusa', 'faits', 'tout', 'cétait', 'êtres', 'commissions']
# Cluster 1 words:
# ['présidente', 'etat', 'américainea', 'partiez', 'paye', 'plusa']
# Cluster 2 words:
# ['villas', 'selona', 'mortes', 'person', 'nordé', 'grouper']
# Cluster 3 words:
# ['match', 'final', 'pointe', 'saisons', 'deux', 'après']
# Cluster 4 words:
# ['suissea', 'fédérales', 'conseils', 'plusa', 'francea', 'cétait']
#
# 2016007-2016008:
# Cluster 0 words:
# ['suissea', 'plusa', 'fédérales', 'conseils', 'francea', 'cétait']
# Cluster 1 words:
# ['saisons', 'final', 'buté', 'pointe', 'deux', 'premiers']
# Cluster 2 words:
# ['plusa', 'avril', 'cétait', 'faits', 'tout', 'êtres']
# Cluster 3 words:
# ['etat', 'américainea', 'unis', 'grouper', 'présidente', 'contrera']
# Cluster 4 words:
# ['présidente', 'ministre', 'paye', 'partiez', 'sociét', 'gouvernait']
#
# 2016006-2016007:
# Cluster 0 words:
# ['plusa', 'cétait', 'faits', 'tout', 'series', 'êtres']
# Cluster 1 words:
# ['attentats', 'bruxelles', 'terroriste', 'paris', 'francea', 'mortes']
# Cluster 2 words:
# ['match', 'saisons', 'final', 'buté', 'pointe', 'équipera']
# Cluster 3 words:
# ['suissea', 'plusa', 'francea', 'milliona', 'conseils', 'fédérales']
# Cluster 4 words:
# ['présidente', 'etat', 'américainea', 'unis', 'paye', 'contrera']
#
# 2016005-2016006:
# Cluster 0 words:
# ['attentats', 'policées', 'paris', 'person', 'mortes', 'enquêter']
# Cluster 1 words:
# ['match', 'saisons', 'pointe', 'buté', 'final', 'équipera']
# Cluster 2 words:
# ['plusa', 'cétait', 'faits', 'êtres', 'tout', 'marai']
# Cluster 3 words:
# ['suissea', 'milliona', 'francea', 'plusa', 'conseils', 'fédérales']
# Cluster 4 words:
# ['etat', 'américainea', 'présidente', 'unis', 'nordé', 'plusa']
#
# 2016004-2016005:
# Cluster 0 words:
# ['etat', 'américainea', 'unis', 'nordé', 'grouper', 'présidente']
# Cluster 1 words:
# ['pointe', 'buté', 'final', 'premiers', 'deux', 'équipera']
# Cluster 2 words:
# ['plusa', 'faits', 'êtres', 'cétait', 'tout', 'après']
# Cluster 3 words:
# ['francea', 'milliona', 'européenn', 'plusa', 'paye', 'présidente']
# Cluster 4 words:
# ['suissea', 'fédérales', 'conseils', 'plusa', 'partiez', 'cétait']
#
# 2016003-2016004:
# Cluster 0 words:
# ['pointe', 'final', 'minute', 'premiers', 'deux', 'fac']
# Cluster 1 words:
# ['suissea', 'francea', 'plusa', 'milliona', 'fédérales', 'conseils']
# Cluster 2 words:
# ['etat', 'américainea', 'contrera', 'unis', 'plusa', 'selona']
# Cluster 3 words:
# ['plusa', 'tout', 'faits', 'cétait', 'êtres', 'commissions']
# Cluster 4 words:
# ['européenn', 'ministre', 'paye', 'gouvernait', 'accordait', 'europe']
#
# 2016002-2016003:
# Cluster 0 words:
# ['plusa', 'tout', 'cétait', 'faits', 'commissions', 'mêmes']
# Cluster 1 words:
# ['policées', 'person', 'mortes', 'selona', 'hommasse', 'attaquaient']
# Cluster 2 words:
# ['etat', 'présidente', 'paye', 'américainea', 'plusa', 'ministre']
# Cluster 3 words:
# ['match', 'final', 'pointe', 'premiers', 'fac', 'deux']
# Cluster 4 words:
# ['suissea', 'francea', 'milliard', 'plusa', 'milliona', 'fédérales']
#
# 2016001-2016002:
# Cluster 0 words:
# ['etat', 'américainea', 'milliona', 'plusa', 'présidente', 'unis']
# Cluster 1 words:
# ['match', 'final', 'pointe', 'premiers', 'deux', 'fac']
# Cluster 2 words:
# ['policées', 'person', 'selona', 'mortes', 'attaquaient', 'villas']
# Cluster 3 words:
# ['suissea', 'fédérales', 'conseils', 'francea', 'plusa', 'économiquement']
# Cluster 4 words:
# ['plusa', 'tout', 'series', 'cétait', 'commissions', 'faits']
#
# 2015024-2016001:
# Cluster 0 words:
# ['plusa', 'tout', 'faits', 'cétait', 'series', 'commissions']
# Cluster 1 words:
# ['saisons', 'pointe', 'couperai', 'minute', 'premiers', 'deux']
# Cluster 2 words:
# ['milliona', 'etat', 'américainea', 'présidente', 'plusa', 'unis']
# Cluster 3 words:
# ['suissea', 'fédérales', 'conseils', 'plusa', 'partiez', 'anné']
# Cluster 4 words:
# ['policées', 'attentats', 'person', 'mortes', 'attaquaient', 'contrera']
#
# 2015023-2015024:
# Cluster 0 words:
# ['buté', 'pointe', 'marquerait', 'premiers', 'après', 'tiraient']
# Cluster 1 words:
# ['plusa', 'cétait', 'faits', 'tout', 'premiers', 'deux']
# Cluster 2 words:
# ['paye', 'présidente', 'milliona', 'etat', 'plusa', 'américainea']
# Cluster 3 words:
# ['policées', 'attentats', 'terroriste', 'person', 'islami', 'mortes']
# Cluster 4 words:
# ['suissea', 'fédérales', 'conseils', 'plusa', 'partiez', 'êtres']
#
# 2015022-2015023:
# Cluster 0 words:
# ['paye', 'etat', 'présidente', 'accordait', 'américainea', 'contrera']
# Cluster 1 words:
# ['suissea', 'fédérales', 'conseils', 'plusa', 'partiez', 'nationales']
# Cluster 2 words:
# ['attentats', 'policées', 'paris', 'francea', 'terroriste', 'attaquaient']
# Cluster 3 words:
# ['plusa', 'cétait', 'francea', 'tout', 'faits', 'milliona']
# Cluster 4 words:
# ['match', 'pointe', 'buté', 'final', 'fac', 'premiers']
#
# 2015021-2015022:
# Cluster 0 words:
# ['plusa', 'cétait', 'faits', 'milliona', 'tout', 'deux']
# Cluster 1 words:
# ['attentats', 'paris', 'francea', 'attaquaient', 'terroriste', 'contrera']
# Cluster 2 words:
# ['match', 'final', 'pointe', 'fac', 'joués', 'deux']
# Cluster 3 words:
# ['suissea', 'conseils', 'fédérales', 'plusa', 'francea', 'etat']
# Cluster 4 words:
# ['russa', 'syrie', 'présidente', 'contrera', 'déclaratives', 'selona']
#
# 2015020-2015021:
# Cluster 0 words:
# ['russa', 'présidente', 'etat', 'grouper', 'octobre', 'selona']
# Cluster 1 words:
# ['match', 'final', 'pointe', 'deux', 'premiers', 'fac']
# Cluster 2 words:
# ['francea', 'milliona', 'octobre', 'présidente', 'cétait', 'plusa']
# Cluster 3 words:
# ['plusa', 'suissea', 'tout', 'cétait', 'auss', 'faits']
# Cluster 4 words:
# ['conseils', 'fédérales', 'partiez', 'suissea', 'droitea', 'nationales']
#
# 2015019-2015020:
# Cluster 0 words:
# ['policées', 'américainea', 'selona', 'villas', 'mortes', 'attaquaient']
# Cluster 1 words:
# ['plusa', 'suissea', 'francea', 'cétait', 'partiez', 'milliona']
# Cluster 2 words:
# ['russa', 'etat', 'octobre', 'grouper', 'contrera', 'présidente']
# Cluster 3 words:
# ['octobre', 'plusa', 'samedis', 'américainea', 'grouper', 'cétait']
# Cluster 4 words:
# ['match', 'final', 'premiers', 'deux', 'équipera', 'fac']
#
# 2015018-2015019:
# Cluster 0 words:
# ['plusa', 'tout', 'premiers', 'deux', 'series', 'cétait']
# Cluster 1 words:
# ['plusa', 'policées', 'selona', 'américainea', 'cétait', 'avoir']
# Cluster 2 words:
# ['suissea', 'francea', 'plusa', 'fédérales', 'milliona', 'conseils']
# Cluster 3 words:
# ['septembres', 'syriennes', 'syrie', 'réfugiées', 'paye', 'européenn']
# Cluster 4 words:
# ['octobre', 'syrie', 'syriennes', 'samedis', 'grouper', 'plusa']
#
# 2015017-2015018:
# Cluster 0 words:
# ['etat', 'présidente', 'contrera', 'grouper', 'plusa', 'selona']
# Cluster 1 words:
# ['septembres', 'plusa', 'syriennes', 'paye', 'réfugiées', 'cétait']
# Cluster 2 words:
# ['suissea', 'francea', 'plusa', 'fédérales', 'conseils', 'milliona']
# Cluster 3 words:
# ['réfugiées', 'migrante', 'frontiera', 'accueilleront', 'européenn', 'paye']
# Cluster 4 words:
# ['plusa', 'tout', 'deux', 'premiers', 'faits', 'cétait']
#
# 2015016-2015017:
# Cluster 0 words:
# ['migrante', 'réfugiées', 'frontiera', 'accueilleront', 'européenn', 'paye']
# Cluster 1 words:
# ['plusa', 'faits', 'tout', 'cétait', 'êtres', 'faires']
# Cluster 2 words:
# ['final', 'tourer', 'fac', 'premiers', 'deux', 'grandirent']
# Cluster 3 words:
# ['suissea', 'francea', 'fédérales', 'plusa', 'conseils', 'économiquement']
# Cluster 4 words:
# ['présidente', 'contrera', 'plusa', 'etat', 'deux', 'afp']
#
# 2015015-2015016:
# Cluster 0 words:
# ['suissea', 'fédérales', 'conseils', 'plusa', 'partiez', 'politiste']
# Cluster 1 words:
# ['plusa', 'faits', 'tout', 'cétait', 'series', 'faires']
# Cluster 2 words:
# ['plusa', 'paye', 'contrera', 'mortes', 'afp', 'selona']
# Cluster 3 words:
# ['francea', 'milliona', 'grouper', 'plusa', 'américainea', 'cétait']
# Cluster 4 words:
# ['final', 'premiers', 'mondialistes', 'grandirent', 'series', 'deux']
#
# 2015014-2015015:
# Cluster 0 words:
# ['juillettistes', 'plusa', 'cétait', 'mardis', 'depuis', 'lunda']
# Cluster 1 words:
# ['francea', 'milliona', 'grouper', 'plusa', 'suissea', 'affairée']
# Cluster 2 words:
# ['plusa', 'cétait', 'series', 'faits', 'deux', 'tout']
# Cluster 3 words:
# ['contrera', 'attaquaient', 'paye', 'afp', 'etat', 'plusa']
# Cluster 4 words:
# ['suissea', 'plusa', 'paye', 'conseils', 'partiez', 'auss']
#
# 2015013-2015014:
# Cluster 0 words:
# ['final', 'fac', 'premiers', 'dernier', 'deux', 'grandirent']
# Cluster 1 words:
# ['selona', 'afp', 'etat', 'contrera', 'mortes', 'présidente']
# Cluster 2 words:
# ['accordait', 'européenn', 'ministre', 'paye', 'gouvernait', 'zoner']
# Cluster 3 words:
# ['juillettistes', 'plusa', 'cétait', 'mardis', 'depuis', 'premiers']
# Cluster 4 words:
# ['plusa', 'suissea', 'series', 'cétait', 'tout', 'francea']
#
# 2015012-2015013:
# Cluster 0 words:
# ['final', 'fac', 'tourer', 'premiers', 'deux', 'dernier']
# Cluster 1 words:
# ['plusa', 'juillettistes', 'tout', 'series', 'faits', 'cétait']
# Cluster 2 words:
# ['européenn', 'accordait', 'ministre', 'zoner', 'gouvernait', 'paye']
# Cluster 3 words:
# ['selona', 'etat', 'afp', 'mortes', 'contrera', 'person']
# Cluster 4 words:
# ['suissea', 'plusa', 'francea', 'milliona', 'conseils', 'fédérales']
#
# 2015011-2015012:
# Cluster 0 words:
# ['présidente', 'francea', 'milliona', 'européenn', 'etat', 'ministre']
# Cluster 1 words:
# ['selona', 'person', 'contrera', 'mortes', 'villas', 'policées']
# Cluster 2 words:
# ['final', 'premiers', 'fac', 'deux', 'couperai', 'plusa']
# Cluster 3 words:
# ['plusa', 'suissea', 'tout', 'faits', 'series', 'cétait']
# Cluster 4 words:
# ['juin', 'prèsa', 'plusa', 'depuis', 'vendredis', 'jeune']
#
# 2015010-2015011:
# Cluster 0 words:
# ['contrera', 'villas', 'selona', 'mortes', 'afp', 'nordé']
# Cluster 1 words:
# ['final', 'fac', 'couperai', 'premiers', 'joués', 'deux']
# Cluster 2 words:
# ['suissea', 'milliona', 'francea', 'plusa', 'conseils', 'projeta']
# Cluster 3 words:
# ['présidente', 'américainea', 'européenn', 'paye', 'ministre', 'etat']
# Cluster 4 words:
# ['plusa', 'juin', 'tout', 'faits', 'cétait', 'femmea']
#
# 2015009-2015010:
# Cluster 0 words:
# ['maier', 'villas', 'policées', 'contrera', 'nordé', 'selona']
# Cluster 1 words:
# ['final', 'fac', 'premiers', 'dernier', 'deux', 'joués']
# Cluster 2 words:
# ['plusa', 'cétait', 'faits', 'tout', 'series', 'deux']
# Cluster 3 words:
# ['suissea', 'milliona', 'francea', 'fédérales', 'plusa', 'conseils']
# Cluster 4 words:
# ['présidente', 'paye', 'etat', 'européenn', 'partiez', 'ministre']
#
# 2015008-2015009:
# Cluster 0 words:
# ['milliona', 'francea', 'plusa', 'selona', 'suissea', 'partiez']
# Cluster 1 words:
# ['paye', 'avril', 'plusa', 'selona', 'mortes', 'afp']
# Cluster 2 words:
# ['plusa', 'faits', 'tout', 'cétait', 'deux', 'series']
# Cluster 3 words:
# ['suissea', 'fédérales', 'conseils', 'plusa', 'contrera', 'partiez']
# Cluster 4 words:
# ['final', 'pointe', 'premiers', 'deux', 'fac', 'après']
#
# 2015007-2015008:
# Cluster 0 words:
# ['selona', 'afp', 'contrera', 'plusa', 'mortes', 'paye']
# Cluster 1 words:
# ['suissea', 'fédérales', 'plusa', 'conseils', 'francea', 'économiquement']
# Cluster 2 words:
# ['francea', 'milliona', 'plusa', 'partiez', 'suissea', 'affairée']
# Cluster 3 words:
# ['avril', 'paye', 'plusa', 'contrera', 'person', 'annonceront']
# Cluster 4 words:
# ['plusa', 'deux', 'tout', 'faits', 'cétait', 'series']
#
# 2015006-2015007:
# Cluster 0 words:
# ['plusa', 'tout', 'series', 'cétait', 'faits', 'premiers']
# Cluster 1 words:
# ['selona', 'afp', 'deux', 'aviona', 'mortes', 'contrera']
# Cluster 2 words:
# ['suissea', 'francea', 'milliona', 'plusa', 'cétait', 'paye']
# Cluster 3 words:
# ['accordait', 'etat', 'marai', 'présidente', 'russa', 'ministre']
# Cluster 4 words:
# ['avril', 'cétait', 'jeudi', 'contrera', 'plusa', 'deux']
#
# 2015005-2015006:
# Cluster 0 words:
# ['plusa', 'cétait', 'tout', 'faits', 'series', 'deux']
# Cluster 1 words:
# ['selona', 'mortes', 'policées', 'deux', 'afp', 'hommasse']
# Cluster 2 words:
# ['marai', 'accordait', 'etat', 'américainea', 'unis', 'ministre']
# Cluster 3 words:
# ['suissea', 'francea', 'milliona', 'plusa', 'conseils', 'fédérales']
# Cluster 4 words:
# ['russa', 'présidente', 'avoir', 'déclaratives', 'affirmerais', 'depuis']
#
# 2015004-2015005:
# Cluster 0 words:
# ['présidente', 'etat', 'ministre', 'accordait', 'contrera', 'gouvernait']
# Cluster 1 words:
# ['milliona', 'francea', 'plusa', 'cétait', 'suissea', 'grouper']
# Cluster 2 words:
# ['suissea', 'francea', 'plusa', 'fédérales', 'cétait', 'auss']
# Cluster 3 words:
# ['policées', 'attaquaient', 'villas', 'nordé', 'hommasse', 'selona']
# Cluster 4 words:
# ['plusa', 'cétait', 'series', 'faits', 'deux', 'tout']
#
# 2015003-2015004:
# Cluster 0 words:
# ['milliona', 'francea', 'suissea', 'plusa', 'grouper', 'cétait']
# Cluster 1 words:
# ['suissea', 'européenn', 'conseils', 'plusa', 'ministre', 'francea']
# Cluster 2 words:
# ['plusa', 'tout', 'cétait', 'faits', 'bien', 'series']
# Cluster 3 words:
# ['février', 'series', 'après', 'jeune', 'hommasse', 'annonceront']
# Cluster 4 words:
# ['islami', 'contrera', 'attaquaient', 'arméea', 'mortes', 'etat']
#
# 2015002-2015003:
# Cluster 0 words:
# ['islami', 'contrera', 'mortes', 'attaquaient', 'arméea', 'terroriste']
# Cluster 1 words:
# ['final', 'mondialistes', 'premiers', 'deux', 'titrant', 'cétait']
# Cluster 2 words:
# ['suissea', 'francea', 'tauxe', 'banque', 'euroa', 'économiquement']
# Cluster 3 words:
# ['plusa', 'cétait', 'partiez', 'présidente', 'dernier', 'février']
# Cluster 4 words:
# ['plusa', 'jeune', 'tout', 'femmea', 'faits', 'êtres']
#
# 2015001-2015002:
# Cluster 0 words:
# ['janvier', 'francea', 'suissea', 'person', 'journal', 'plusa']
# Cluster 1 words:
# ['suissea', 'francea', 'banque', 'euroa', 'économiquement', 'plusa']
# Cluster 2 words:
# ['contrera', 'etat', 'présidente', 'selona', 'plusa', 'cétait']
# Cluster 3 words:
# ['plusa', 'final', 'premiers', 'series', 'cétait', 'deux']
# Cluster 4 words:
# ['charl', 'hebdo', 'journal', 'francea', 'attentats', 'paris']
#
# 2014024-2015001:
# Cluster 0 words:
# ['suissea', 'plusa', 'anné', 'cétait', 'francea', 'series']
# Cluster 1 words:
# ['etat', 'américainea', 'présidente', 'nordé', 'unis', 'contrera']
# Cluster 2 words:
# ['femmea', 'jeune', 'deux', 'selona', 'enfantement', 'plusa']
# Cluster 3 words:
# ['charl', 'hebdo', 'francea', 'journal', 'attentats', 'paris']
# Cluster 4 words:
# ['janvier', 'francea', 'suissea', 'journal', 'paris', 'person']
#
# 2014023-2014024:
# Cluster 0 words:
# ['femmea', 'plusa', 'bien', 'faits', 'très', 'jeune']
# Cluster 1 words:
# ['contrera', 'attaquaient', 'arméea', 'policées', 'mortes', 'nordé']
# Cluster 2 words:
# ['décembre', 'paye', 'plusa', 'selona', 'journal', 'etat']
# Cluster 3 words:
# ['plusa', 'milliona', 'cétait', 'francea', 'etat', 'présidente']
# Cluster 4 words:
# ['suissea', 'plusa', 'francea', 'cétait', 'anné', 'fédérales']
#
# 2014022-2014023:
# Cluster 0 words:
# ['plusa', 'faits', 'final', 'tout', 'couperai', 'francea']
# Cluster 1 words:
# ['novembres', 'plusa', 'jeune', 'mortes', 'hommasse', 'selona']
# Cluster 2 words:
# ['plusa', 'contrera', 'cétait', 'selona', 'depuis', 'afp']
# Cluster 3 words:
# ['suissea', 'conseils', 'fédérales', 'plusa', 'francea', 'milliona']
# Cluster 4 words:
# ['décembre', 'paye', 'plusa', 'selona', 'novembres', 'etat']
#
# 2014021-2014022:
# Cluster 0 words:
# ['novembres', 'islami', 'octobre', 'plusa', 'contrera', 'person']
# Cluster 1 words:
# ['etat', 'contrera', 'afp', 'selona', 'plusa', 'présidente']
# Cluster 2 words:
# ['plusa', 'faits', 'tout', 'cétait', 'final', 'deux']
# Cluster 3 words:
# ['suissea', 'fédérales', 'milliona', 'plusa', 'francea', 'conseils']
# Cluster 4 words:
# ['u0092estiment', 'tout', 'bien', 'plusa', 'faires', 'faits']
#
# 2014020-2014021:
# Cluster 0 words:
# ['final', 'pointe', 'premiers', 'fac', 'couperai', 'deux']
# Cluster 1 words:
# ['octobre', 'contrera', 'etat', 'journal', 'novembres', 'paye']
# Cluster 2 words:
# ['etat', 'afp', 'contrera', 'américainea', 'plusa', 'policées']
# Cluster 3 words:
# ['plusa', 'faits', 'tout', 'jeune', 'femmea', 'faires']
# Cluster 4 words:
# ['suissea', 'milliona', 'plusa', 'francea', 'fédérales', 'paye']
#
# 2014019-2014020:
# Cluster 0 words:
# ['suissea', 'milliona', 'francea', 'plusa', 'fédérales', 'partiez']
# Cluster 1 words:
# ['octobre', 'modifiable', 'ebola', 'etat', 'islami', 'journal']
# Cluster 2 words:
# ['ebola', 'virus', 'maladie', 'caser', 'sant', 'afrique']
# Cluster 3 words:
# ['plusa', 'cétait', 'series', 'deux', 'tout', 'final']
# Cluster 4 words:
# ['villas', 'arméea', 'syrie', 'etat', 'américainea', 'força']
#
# 2014018-2014019:
# Cluster 0 words:
# ['syrie', 'contrera', 'syriennes', 'frappants', 'islami', 'etat']
# Cluster 1 words:
# ['octobre', 'modifiable', '2014les', 'ebola', 'etat', 'islami']
# Cluster 2 words:
# ['plusa', 'cétait', 'francea', 'suissea', 'tout', 'deux']
# Cluster 3 words:
# ['septembres', 'modifiable', '2014les', 'islami', 'etat', 'contrera']
# Cluster 4 words:
# ['ebola', 'maladie', 'sant', 'caser', 'person', 'mortes']
#
# 2014017-2014018:
# Cluster 0 words:
# ['suissea', 'milliona', 'plusa', 'conseils', 'fédérales', 'francea']
# Cluster 1 words:
# ['septembres', 'modifiable', 'islami', 'etat', 'contrera', 'syrie']
# Cluster 2 words:
# ['iraki', 'syrie', 'islami', 'etat', 'contrera', 'frappants']
# Cluster 3 words:
# ['plusa', 'tout', 'series', 'faits', 'bien', 'mêmes']
# Cluster 4 words:
# ['selona', 'plusa', 'cétait', 'francea', 'présidente', 'faits']
#
# 2014016-2014017:
# Cluster 0 words:
# ['selona', 'mortes', 'porterais', 'afp', 'plusa', 'cétait']
# Cluster 1 words:
# ['islami', 'syrie', 'etat', 'américainea', 'contrera', 'nordé']
# Cluster 2 words:
# ['suissea', 'francea', 'plusa', 'milliona', 'conseils', 'fédérales']
# Cluster 3 words:
# ['plusa', 'tout', 'jeune', 'faits', 'series', 'deux']
# Cluster 4 words:
# ['septembres', 'modifiable', 'islami', 'etat', 'journal', 'contrera']
#
# 2014015-2014016:
# Cluster 0 words:
# ['modifiable', 'islami', 'etat', 'journal', 'américainea', 'contrera']
# Cluster 1 words:
# ['suissea', 'fédérales', 'conseils', 'francea', 'plusa', 'milliona']
# Cluster 2 words:
# ['gazait', 'feua', 'tiraient', 'arméea', 'civil', 'mortes']
# Cluster 3 words:
# ['paye', 'contrera', 'etat', 'plusa', 'ministre', 'afp']
# Cluster 4 words:
# ['plusa', 'series', 'tout', 'faits', 'cétait', 'premiers']
#
# 2014014-2014015:
# Cluster 0 words:
# ['juillettistes', 'mercredes', 'jeudi', 'mardis', 'bandée', 'grandirent']
# Cluster 1 words:
# ['etat', 'paye', 'contrera', 'présidente', 'person', 'américainea']
# Cluster 2 words:
# ['plusa', 'tout', 'series', 'faits', 'cétait', 'deux']
# Cluster 3 words:
# ['suissea', 'milliona', 'francea', 'fédérales', 'conseils', 'plusa']
# Cluster 4 words:
# ['israéliens', 'palestinien', 'gazait', 'isra', 'hama', 'bandée']
#
# 2014013-2014014:
# Cluster 0 words:
# ['juillettistes', 'festival', 'bandée', 'jeudi', 'mercredes', 'vendredis']
# Cluster 1 words:
# ['israéliens', 'palestinien', 'gazait', 'isra', 'arméea', 'bandée']
# Cluster 2 words:
# ['selona', 'etat', 'présidente', 'cétait', 'person', 'contrera']
# Cluster 3 words:
# ['plusa', 'final', 'tout', 'series', 'cétait', 'suissea']
# Cluster 4 words:
# ['u0092estiment', 'plusa', 'tout', 'joués', 'festival', 'bien']
#
# 2014012-2014013:
# Cluster 0 words:
# ['u0092estiment', 'plusa', 'tout', 'joués', 'bien', 'faits']
# Cluster 1 words:
# ['final', 'match', 'joueur', 'tourer', 'couperai', 'équipera']
# Cluster 2 words:
# ['etat', 'selona', 'arméea', 'porterais', 'contrera', 'présidente']
# Cluster 3 words:
# ['plusa', 'suissea', 'series', 'francea', 'cétait', 'tout']
# Cluster 4 words:
# ['juin', 'juillettistes', 'etat', 'contrera', 'paye', 'entres']
#
# 2014011-2014012:
# Cluster 0 words:
# ['juin', 'samedis', 'prèsa', 'journal', 'paye', 'suissea']
# Cluster 1 words:
# ['selona', 'cétait', 'plusa', 'présidente', 'francea', 'conseils']
# Cluster 2 words:
# ['plusa', 'u0092estiment', 'tout', 'series', 'commissions', 'faits']
# Cluster 3 words:
# ['match', 'final', 'mondialistes', 'premiers', 'équipera', 'fac']
# Cluster 4 words:
# ['américainea', 'etat', 'unis', 'présidente', 'contrera', 'avoir']
#
# 2014010-2014011:
# Cluster 0 words:
# ['u0092estiment', 'plusa', 'tout', 'final', 'premiers', 'jeune']
# Cluster 1 words:
# ['russa', 'présidente', 'déclaratives', 'paye', 'ministre', 'américainea']
# Cluster 2 words:
# ['plusa', 'cétait', 'selona', 'etat', 'maier', 'présidente']
# Cluster 3 words:
# ['juin', 'prèsa', 'samedis', 'vendredis', 'présidente', 'teller']
# Cluster 4 words:
# ['suissea', 'fédérales', 'plusa', 'conseils', 'milliona', 'autre']
#
# 2014009-2014010:
# Cluster 0 words:
# ['maier', 'milliona', 'présidente', 'avril', 'plusa', 'francea']
# Cluster 1 words:
# ['plusa', 'final', 'tout', 'cétait', 'deux', 'premiers']
# Cluster 2 words:
# ['selona', 'plusa', 'afp', 'policées', 'cétait', 'présidente']
# Cluster 3 words:
# ['suissea', 'fédérales', 'milliard', 'plusa', 'conseils', 'francea']
# Cluster 4 words:
# ['russa', 'présidente', 'paye', 'déclaratives', 'régions', 'contrera']
#
# 2014008-2014009:
# Cluster 0 words:
# ['plusa', 'selona', 'afp', 'milliona', 'francea', 'maier']
# Cluster 1 words:
# ['avril', 'russa', 'arméea', 'ukrainisme', 'jeudi', 'paye']
# Cluster 2 words:
# ['plusa', 'final', 'deux', 'tout', 'cétait', 'series']
# Cluster 3 words:
# ['russa', 'ukrainisme', 'ukrainiens', 'présidente', 'déclaratives', 'militaires']
# Cluster 4 words:
# ['suissea', 'plusa', 'fédérales', 'conseils', 'contrera', 'cétait']
#
# 2014007-2014008:
# Cluster 0 words:
# ['russa', 'ukrainisme', 'ukrainiens', 'européenn', 'présidente', 'déclaratives']
# Cluster 1 words:
# ['suissea', 'francea', 'plusa', 'milliona', 'conseils', 'fédérales']
# Cluster 2 words:
# ['avril', 'russa', 'ukrainisme', 'ukrainiens', 'paye', 'contrera']
# Cluster 3 words:
# ['plusa', 'tout', 'final', 'deux', 'series', 'faits']
# Cluster 4 words:
# ['deux', 'après', 'plusa', 'afp', 'selona', 'avoir']
#
# 2014006-2014007:
# Cluster 0 words:
# ['russa', 'ukrainisme', 'crimes', 'ukrainiens', 'marai', 'présidente']
# Cluster 1 words:
# ['avril', 'modifiable', 'russa', 'ukrainisme', 'ukrainiens', 'cétait']
# Cluster 2 words:
# ['suissea', 'francea', 'fédérales', 'milliona', 'conseils', 'plusa']
# Cluster 3 words:
# ['plusa', 'tout', 'faits', 'series', 'cétait', 'deux']
# Cluster 4 words:
# ['marai', 'plusa', 'deux', 'premiers', 'selona', 'cétait']
#
# 2014005-2014006:
# Cluster 0 words:
# ['plusa', 'tout', 'cétait', 'series', 'faits', 'dernier']
# Cluster 1 words:
# ['porterais', 'plusa', 'cétait', 'après', 'selona', 'afp']
# Cluster 2 words:
# ['marai', 'russa', 'crimes', 'plusa', 'journal', 'selona']
# Cluster 3 words:
# ['russa', 'ukrainisme', 'crimes', 'ukrainiens', 'présidente', 'moscoua']
# Cluster 4 words:
# ['suissea', 'fédérales', 'francea', 'conseils', 'milliona', 'plusa']
#
# 2014004-2014005:
# Cluster 0 words:
# ['russa', 'ukrainisme', 'ukrainiens', 'crimes', 'présidente', 'ministre']
# Cluster 1 words:
# ['selona', 'après', 'plusa', 'cétait', 'francea', 'afp']
# Cluster 2 words:
# ['plusa', 'tout', 'series', 'faits', 'faires', 'mêmes']
# Cluster 3 words:
# ['marai', 'series', 'suissea', 'fédérales', 'journal', 'conseils']
# Cluster 4 words:
# ['suissea', 'février', 'fédérales', 'plusa', 'européenn', 'conseils']
#
# 2014003-2014004:
# Cluster 0 words:
# ['francea', 'milliona', 'cétait', 'américainea', 'plusa', 'etat']
# Cluster 1 words:
# ['février', 'modifiable', 'suissea', 'initiateurs', 'européenn', 'immigrant']
# Cluster 2 words:
# ['suissea', 'initiateurs', 'européenn', 'plusa', 'immigrant', 'voter']
# Cluster 3 words:
# ['afp', 'policées', 'après', 'ministre', 'mortes', 'depuis']
# Cluster 4 words:
# ['plusa', 'tout', 'faits', 'series', 'deux', 'cétait']
#
# 2014002-2014003:
# Cluster 0 words:
# ['janvier', 'présidente', 'etat', 'selona', 'afp', 'depuis']
# Cluster 1 words:
# ['final', 'grandirent', 'meilleura', 'deux', 'premiers', 'joués']
# Cluster 2 words:
# ['février', 'suissea', 'européenn', 'fédérales', 'accordait', 'conseils']
# Cluster 3 words:
# ['plusa', 'tout', 'cétait', 'faits', 'series', 'faires']
# Cluster 4 words:
# ['suissea', 'plusa', 'européenn', 'francea', 'économiquement', 'fédérales']
#
# 2014001-2014002:
# Cluster 0 words:
# ['suissea', 'milliona', 'francea', 'plusa', 'anné', 'grouper']
# Cluster 1 words:
# ['plusa', 'cétait', 'tout', 'faits', 'êtres', 'selona']
# Cluster 2 words:
# ['présidente', 'ministre', 'etat', 'francea', 'chef', 'depuis']
# Cluster 3 words:
# ['janvier', 'etat', 'depuis', 'paye', 'plusa', 'selona']
# Cluster 4 words:
# ['final', 'match', 'premiers', 'deux', 'joués', 'grandirent']
#
# 2013024-2014001:
# Cluster 0 words:
# ['milliona', 'francea', 'anné', 'grouper', 'plusa', 'quelqus']
# Cluster 1 words:
# ['présidente', 'etat', 'ministre', 'cétait', 'afp', 'depuis']
# Cluster 2 words:
# ['final', 'series', 'premiers', 'deux', 'titrant', 'dernier']
# Cluster 3 words:
# ['suissea', 'plusa', 'partiez', 'francea', 'conseils', 'européenn']
# Cluster 4 words:
# ['plusa', 'tout', 'femmea', 'jeune', 'cétait', 'faits']
#
# 2013023-2013024:
# Cluster 0 words:
# ['plusa', 'cétait', 'series', 'deux', 'tout', 'faits']
# Cluster 1 words:
# ['suda', 'présidente', 'ministre', 'gouvernait', 'depuis', 'plusa']
# Cluster 2 words:
# ['américainea', 'etat', 'cétait', 'avoir', 'unis', 'plusa']
# Cluster 3 words:
# ['décembre', 'milliona', 'anné', 'plusa', 'présidente', 'francea']
# Cluster 4 words:
# ['suissea', 'francea', 'milliona', 'plusa', 'fédérales', 'conseils']
#
# 2013022-2013023:
# Cluster 0 words:
# ['suissea', 'plusa', 'fédérales', 'francea', 'conseils', 'milliona']
# Cluster 1 words:
# ['plusa', 'deux', 'tout', 'francea', 'couperai', 'cétait']
# Cluster 2 words:
# ['présidente', 'suda', 'gouvernait', 'ministre', 'paye', 'partiez']
# Cluster 3 words:
# ['u0092estiment', 'series', 'plusa', 'faits', 'faires', 'tout']
# Cluster 4 words:
# ['américainea', 'cétait', 'selona', 'series', 'êtres', 'plusa']
#
# 2013021-2013022:
# Cluster 0 words:
# ['suissea', 'milliona', 'plusa', 'francea', 'fédérales', 'conseils']
# Cluster 1 words:
# ['russa', 'membres', 'cétait', 'après', 'septembres', 'deux']
# Cluster 2 words:
# ['novembres', 'francea', 'plusa', 'person', 'paye', 'gouvernait']
# Cluster 3 words:
# ['plusa', 'cétait', 'selona', 'contrera', 'partiez', 'présidente']
# Cluster 4 words:
# ['u0092estiment', 'plusa', 'tout', 'faits', 'premiers', 'deux']
#
# 2013020-2013021:
# Cluster 0 words:
# ['plusa', 'selona', 'cétait', 'person', 'policées', 'après']
# Cluster 1 words:
# ['u0092estiment', 'tout', 'plusa', 'faits', 'commissions', 'jeune']
# Cluster 2 words:
# ['fac', 'final', 'deux', 'premiers', 'après', 'plusa']
# Cluster 3 words:
# ['francea', 'suissea', 'milliona', 'plusa', 'cétait', 'famille']
# Cluster 4 words:
# ['etat', 'américainea', 'présidente', 'unis', 'ministre', 'cétait']
#
# 2013019-2013020:
# Cluster 0 words:
# ['plusa', 'series', 'final', 'deux', 'premiers', 'dernier']
# Cluster 1 words:
# ['francea', 'suissea', 'partiez', 'conseils', 'cétait', 'socialité']
# Cluster 2 words:
# ['américainea', 'etat', 'unis', 'présidente', 'cétait', 'plusa']
# Cluster 3 words:
# ['octobre', 'selona', 'enfantement', 'mortes', 'person', 'policées']
# Cluster 4 words:
# ['u0092estiment', 'faits', 'tout', 'plusa', 'bien', 'cétait']
#
# 2013018-2013019:
# Cluster 0 words:
# ['septembres', 'suissea', 'plusa', 'paye', 'présidente', 'fédérales']
# Cluster 1 words:
# ['suissea', 'conseils', 'etat', 'francea', 'plusa', 'présidente']
# Cluster 2 words:
# ['selona', 'porterais', 'policées', 'dont', 'afp', 'plusa']
# Cluster 3 words:
# ['u0092estiment', 'u0092unit', 'plusa', 'faits', 'tout', 'bien']
# Cluster 4 words:
# ['plusa', 'cétait', 'premiers', 'final', 'deux', 'series']
#
# 2013017-2013018:
# Cluster 0 words:
# ['septembres', 'suissea', 'plusa', 'person', 'fédérales', 'syriennes']
# Cluster 1 words:
# ['russa', 'chimiquea', 'syriennes', 'syrie', 'arme', 'américainea']
# Cluster 2 words:
# ['u0092estiment', 'u0092unit', 'plusa', 'tout', 'jeune', 'très']
# Cluster 3 words:
# ['plusa', 'suissea', 'cétait', 'contrera', 'partiez', 'francea']
# Cluster 4 words:
# ['final', 'fac', 'premiers', 'couperai', 'plusa', 'pointe']
#
# 2013016-2013017:
# Cluster 0 words:
# ...
#
# 2001009-2001010:
# Cluster 0 words:
# ['series', 'personnage', 'expositions', 'deux', 'tout', 'toujours']
# Cluster 1 words:
# ['herzog', 'meuron', 'muses', 'jacqui', 'architecture', 'architecte']
# Cluster 2 words:
# ['suissea', 'onu', 'sociét', 'clubs', 'découvertes', 'couplé']
# Cluster 3 words:
# ['sitis', 'médicament', 'novartis', 'genèvea', 'loisir', 'prixa']
# Cluster 4 words:
# ['godard', 'filmait', 'jeanie', 'luca', 'amoureusement', 'eloge']
#
# 2001008-2001009:
# Cluster 0 words:
# ['contrera', 'suissea', 'onu', 'sociét', 'transporterons', 'couplé']
# Cluster 1 words:
# ['godard', 'jeanie', 'filmait', 'luca', 'amoureusement', 'eloge']
# Cluster 2 words:
# ['suicida', 'nones', 'series', 'personnage', 'bleues', 'tout']
# Cluster 3 words:
# ['algérienne', 'alger', 'ahmed', 'hocine', 'présidente', 'commission']
# Cluster 4 words:
# ['herzog', 'meuron', 'muses', 'loisir', 'jacqui', 'architecture']
#
# 2001007-2001008:
# Cluster 0 words:
# ['architecte', 'boise', 'anné', 'projeta', 'londre', 'inaugurées']
# Cluster 1 words:
# ['initiateurs', 'projeta', 'conseils', 'fédérales', 'contrera', 'routière']
# Cluster 2 words:
# ['trafic', 'suissea', 'contrera', 'entreprises', 'sécurités', 'transporterons']
# Cluster 3 words:
# ['officera', 'paysans', 'réfugiées', 'fédérales', 'êtres', 'conféderation']
# Cluster 4 words:
# ['droitea', 'suissea', 'nones', 'hommasse', 'enquêter', 'toujours']
#
# 2001006-2001007:
# Cluster 0 words:
# ['paysans', 'nordé', 'plusa', 'suissea', 'développes', 'porterais']
# Cluster 1 words:
# ['sociét', 'affairée', 'arme', 'services', 'justice', 'suissea']
# Cluster 2 words:
# ['droitea', 'réfugiées', 'joura', 'faits', 'alimentées', 'jeanie']
# Cluster 3 words:
# ['projeta', 'conseils', 'fédérales', 'décisions', 'doit', 'refuserai']
# Cluster 4 words:
# ['architecte', 'tout', 'boise', 'prixa', 'projeta', 'anné']
#
# 2001005-2001006:
# Cluster 0 words:
# ['science', 'étudie', 'idé', 'follies', 'europe', 'premiers']
# Cluster 1 words:
# ['tessin', 'cétait', 'art', 'muses', 'commissions', 'suda']
# Cluster 2 words:
# ['sociét', 'docu', 'nouveaux', 'services', 'comptera', 'opérants']
# Cluster 3 words:
# ['droitea', 'décisions', 'étrangères', 'voter', 'doit', 'constituait']
# Cluster 4 words:
# ['centrait', 'universe', 'projeta', 'recherchées', 'milliona', 'genèvea']
#
# 2001004-2001005:
# Cluster 0 words:
# ['milliard', 'anciennement', 'famille', 'fondante', 'comptera', 'francea']
# Cluster 1 words:
# ['cantonais', 'jacqui', 'entreprises', 'sociét', 'commissions', 'muses']
# Cluster 2 words:
# ['david', 'villas', 'science', 'équipera', 'américainea', 'classez']
# Cluster 3 words:
# ['plusa', 'prixa', 'francea', 'paye', 'organisez', 'entraider']
# Cluster 4 words:
# ['droitea', 'fédérales', 'climatiques', 'josepha', 'politiste', 'genevoises']
#
# 2001003-2001004:
# Cluster 0 words:
# ['plusa', 'commissions', 'dernier', 'autre', 'tout', 'anné']
# Cluster 1 words:
# ['genevoises', 'cantonais', 'villas', 'droitea', 'étrangères', 'loi']
# Cluster 2 words:
# ['joueur', 'équipera', 'désormais', 'rencontra', 'cents', 'évoluaient']
# Cluster 3 words:
# ['francea', 'porterais', 'résultats', 'bernardi', 'produite', 'unité']
# Cluster 4 words:
# ['anné', 'plusa', 'très', 'sociét', 'égales', 'entreprises']
#
# 2001002-2001003:
# Cluster 0 words:
# ['filmait', 'cinémas', 'thés', 'tre', 'festival', 'populairea']
# Cluster 1 words:
# ['postait', 'services', 'jeanie', 'savary', 'devrais', 'publica']
# Cluster 2 words:
# ['capes', 'guerrea', 'jami', 'marquerait', 'sanea', 'dernier']
# Cluster 3 words:
# ['suissea', 'légi', 'palestinien', 'étrangères', 'droitea', 'onu']
# Cluster 4 words:
# ['person', 'mortes', 'établissements', 'attendance', 'carter', 'américainea']
#
# 2001001-2001002:
# Cluster 0 words:
# ['sucrant', 'betterave', 'bio', 'productivement', 'frauenfeld', 'allemagne']
# Cluster 1 words:
# ['financeraient', 'partiez', 'bignasca', 'légi', 'dépensant', 'politiste']
# Cluster 2 words:
# ['thés', 'tre', 'zampieri', 'tpr', 'azzurro', 'romande']
# Cluster 3 words:
# ['capes', 'photographée', 'guerrea', 'robert', 'imag', 'marquerait']
# Cluster 4 words:
# ['postait', 'services', 'paule', 'savary', 'officera', 'jeanie']
#
# 2000024-2001001:
# Cluster 0 words:
# ['américainea', 'photographée', 'frank', 'robert', 'new', 'hoboken']
# Cluster 1 words:
# ['financeraient', 'dépensant', 'partiez', 'politiste', 'êtres', 'corruption']
# Cluster 2 words:
# ['sucrant', 'forêt', 'betterave', 'anné', 'bio', 'productivement']
# Cluster 3 words:
# ['aviona', 'pilatus', 'militaires', 'retrouvions', 'appareille', 'très']
# Cluster 4 words:
# ['diams', 'onu', 'rapporterait', 'auprès', 'francea', 'protestants']
#
# 2000023-2000024:
# Cluster 0 words:
# ['aoc', 'suissea', 'onu', 'diams', 'auprès', 'rapporterait']
# Cluster 1 words:
# ['viana', 'bor', 'américainea', 'photographée', 'frank', 'chansons']
# Cluster 2 words:
# ['forêt', 'travail', 'cheron', 'jeanie', 'lothar', 'catastrophisme']
# Cluster 3 words:
# ['aviona', 'rechsteiner', 'pilatus', 'conseils', 'très', 'paule']
# Cluster 4 words:
# ['natures', 'recensera', 'parce', 'proa', 'projeta', 'suissea']
#
# 2000022-2000023:
# Cluster 0 words:
# ['viana', 'recensera', 'bor', 'chansons', 'statistiquement', 'nones']
# Cluster 1 words:
# ['fnac', 'librairies', 'livres', 'diffuseurs', 'prixa', 'marchea']
# Cluster 2 words:
# ['natures', 'aoc', 'proa', 'parce', 'critère', 'fromage']
# Cluster 3 words:
# ['milliard', 'fortune', 'bertarelli', 'grouper', 'ernesto', 'francea']
# Cluster 4 words:
# ['initiateurs', 'rechsteiner', 'transporterons', 'paule', 'brigade', 'mardis']
#
# 2000021-2000022:
# Cluster 0 words:
# ['librairies', 'fnac', 'livres', 'diffuseurs', 'prixa', 'marchea']
# Cluster 1 words:
# ['cio', 'initiateurs', 'cétait', 'accordait', 'ppps', 'participerons']
# Cluster 2 words:
# ['milliard', 'fortune', 'unis', 'américainea', 'bertarelli', 'etat']
# Cluster 3 words:
# ['questionnaires', 'recensera', 'malaguerra', 'décembre', 'données', 'internet']
# Cluster 4 words:
# ['lepera', 'cernant', 'particulie', 'higgs', 'icia', 'puisses']
#
# 2000020-2000021:
# Cluster 0 words:
# ['suissea', 'participerons', 'etat', 'cétait', 'milliona', 'assurer']
# Cluster 1 words:
# ['légendés', 'imag', 'sainté', 'livres', 'selliers', 'dorée']
# Cluster 2 words:
# ['jusqu', 'icia', 'aurer', 'grouper', 'moisie', 'arrivants']
# Cluster 3 words:
# ['chimiquea', 'convention', 'industre', 'suissea', 'économiquement', 'experte']
# Cluster 4 words:
# ['publica', 'suissea', 'citoyennes', 'recensera', 'questionne', 'fédérales']
#
# 2000019-2000020:
# Cluster 0 words:
# ['légendés', 'imag', 'livres', 'sainté', 'dorée', 'selliers']
# Cluster 1 words:
# ['suissea', 'scientifiques', 'milliona', 'lunda', 'publica', 'bilan']
# Cluster 2 words:
# ['partiez', 'socialité', 'présidente', 'brunner', 'services', 'conseils']
# Cluster 3 words:
# ['convention', 'chimiquea', 'suissea', 'industre', 'protocoler', 'loisir']
# Cluster 4 words:
# ['kilométriques', 'marco', 'grouper', 'series', 'après', 'arrivants']
#
# 2000018-2000019:
# Cluster 0 words:
# ['dimitra', 'thés', 'éléphant', 'tre', 'école', 'clowns']
# Cluster 1 words:
# ['partiez', 'présidente', 'brunner', 'conseils', 'socialité', 'services']
# Cluster 2 words:
# ['intégrisme', 'rougie', 'croix', 'cents', 'emblème', 'genèvea']
# Cluster 3 words:
# ['festival', 'irena', 'bignardi', 'marco', 'souhaiteriez', 'cavina']
# Cluster 4 words:
# ['cernant', 'higgs', 'lepera', 'boson', 'scientifiques', 'particulie']
#
# 2000017-2000018:
# Cluster 0 words:
# ['dimitra', 'thés', 'éléphant', 'tre', 'école', 'clowns']
# Cluster 1 words:
# ['rougie', 'emblème', 'croix', 'mouvantes', 'diplomaties', 'nouvelle']
# Cluster 2 words:
# ['magnum', 'photographée', 'monde', 'montres', 'expositions', 'conscience']
# Cluster 3 words:
# ['yakari', 'carcajou', 'volée', 'albums', 'histoirea', 'gloutons']
# Cluster 4 words:
# ['intégrisme', 'victimea', 'cents', 'fondante', 'demandai', 'commission']
#
# 2000016-2000017:
# Cluster 0 words:
# ['magnum', 'bykov', 'slave', 'monde', 'photographée', 'fribourga']
# Cluster 1 words:
# ['rougie', 'emblème', 'croix', 'mouvantes', 'diplomaties', 'genèvea']
# Cluster 2 words:
# ['victimea', 'fondante', 'demandai', 'francea', 'attentats', 'versées']
# Cluster 3 words:
# ['yakari', 'carcajou', 'volée', 'derib', 'albums', 'gloutons']
# Cluster 4 words:
# ['enseigné', 'romande', 'éleves', 'éducatrice', 'école', 'étudie']
#
# 2000015-2000016:
# Cluster 0 words:
# ['bykov', 'slave', 'fribourga', 'glacis', 'gottéron', 'titrant']
# Cluster 1 words:
# ['enseigné', 'romande', 'éleves', 'éducatrice', 'pecaro', 'objection']
# Cluster 2 words:
# ['torracinta', 'néonazi', 'clauda', 'contrera', 'racisme', 'metzler']
# Cluster 3 words:
# ['parce', 'réserver', 'km2', 'naturela', 'extension', 'lacé']
#
# 2000014-2000015:
# Cluster 0 words:
# ['parce', 'réserver', 'nationales', 'km2', 'commune', 'projeta']
# Cluster 1 words:
# ['frere', 'alexi', 'travaille', 'lamberts', 'êtres', 'lecteurs']
# Cluster 2 words:
# ['clauda', 'torracinta', 'néonazi', 'contrera', 'ruth', 'metzler']
#
# 2000013-2000014:
# Cluster 0 words:
# ['travaille', 'alexi', 'frere', 'lamberts', 'êtres', 'mercata']
# Cluster 1 words:
# ['paye', 'listera', 'financier', 'plusa', 'tout', 'autor']
# Cluster 2 words:
# ['fnac', 'prixa', 'librairies', 'éditeur', 'livres', 'françaises']
#
# 2000011-2000013:
# Cluster 0 words:
# ['paye', 'financier', 'listera', 'ministre', 'autor', 'blanchissement']
# Cluster 1 words:
# ['communauté', 'libérala', 'juifs', 'fsci', 'juives', 'orthodoxes']
# Cluster 2 words:
# ['campagne', 'nombreuses', 'affiche', 'annonceront', 'encores', 'xénophobie']
# Cluster 3 words:
# ['fnac', 'prixa', 'livres', 'librairies', 'éditeur', 'romande']
#
# 2000006-2000011:
# Cluster 0 words:
# ['donneurs', 'organes', 'grefferaient', 'tropez', 'transplantation', 'mortes']
# Cluster 1 words:
# ['naturalisations', 'étrangères', 'politiste', 'emmènerait', 'cfe', 'commission']
# Cluster 2 words:
# ['filmait', 'favrod', 'fixes', 'charl', 'muses', 'henri']
# Cluster 3 words:
# ['campagne', 'nombreuses', 'schild', 'annonceront', 'affiche', 'xénophobie']
# Cluster 4 words:
# ['communauté', 'libérala', 'juifs', 'juives', 'fsci', 'orthodoxes']
#
# 2000005-2000006:
# Cluster 0 words:
# ['organes', 'donneurs', 'mortes', 'grefferaient', 'transplantation', 'tropez']
# Cluster 1 words:
# ['politiste', 'démocrate', 'soluté', 'naturalisations', 'not', 'réglementée']
# Cluster 2 words:
# ['filmait', 'favrod', 'fixes', 'henri', 'charl', 'muses']
# Cluster 3 words:
# ['cfe', 'commission', 'intégrisme', 'participerons', 'migrante', 'insertion']
# Cluster 4 words:
# ['étrangères', 'naturalisations', 'commune', 'lucernoises', 'emmènerait', 'demandai']
#
# 2000003-2000005:
# Cluster 0 words:
# ['jouets', 'premiers', 'woody', 'animistes', 'lasseter', 'sanea']
# Cluster 1 words:
# ['étrangères', 'naturalisations', 'cantonais', 'commune', 'emmènerait', 'demandai']
# Cluster 2 words:
# ['politiste', 'europe', 'haider', 'européenn', 'senarclens', 'autrich']
# Cluster 3 words:
# ['lamberts', 'pfizer', 'warn', 'américainea', 'fusions', 'milliard']
# Cluster 4 words:
# ['boise', 'forêt', 'étatistes', 'majorations', 'milliona', 'lothar']
#
# 2000002-2000003:
# Cluster 0 words:
# ['pfizer', 'lamberts', 'warn', 'américainea', 'dollari', 'milliard']
# Cluster 1 words:
# ['jouets', 'premiers', 'woody', 'animistes', 'lasseter', 'sanea']
# Cluster 2 words:
# ['boise', 'majorations', 'forêt', 'étatistes', 'proposeraient', 'lothar']
# Cluster 3 words:
# ['europe', 'politiste', 'haider', 'européenn', 'autrich', 'senarclens']
# Cluster 4 words:
# ['deux', 'grouper', 'beecham', 'smithkline', 'rumeurs', 'wellcome']
#
# 1999024-2000002:
# Cluster 0 words:
# ['deux', 'beecham', 'smithkline', 'wellcome', 'rumeurs', 'britanniques']
# Cluster 1 words:
# ['sainté', 'nicols', 'personnage', 'coutume', 'catholique', 'allemagne']
# Cluster 2 words:
# ['loi', 'cétait', 'etat', 'monopol', 'unis', 'oils']
#
# 1999023-1999024:
# Cluster 0 words:
# ['romande', 'socialité', 'dimanchea', 'cents', 'conseils', 'sondage']
# Cluster 1 words:
# ['sainté', 'nicols', 'personnage', 'coutume', 'allemagne', 'manteau']
# Cluster 2 words:
# ['loi', 'cétait', 'standards', 'monopol', 'etat', 'oils']
# Cluster 3 words:
# ['gouvernementale', 'septante', 'politiste', 'peut', 'suissea', 'mercredes']
# Cluster 4 words:
# ['yakari', 'derib', 'pétasse', 'series', 'tout', 'albums']
#
# 1999022-1999023:
# Cluster 0 words:
# ['yello', 'techno', 'meyer', 'musiques', 'diet', 'aimerais']
# Cluster 1 words:
# ['romande', 'socialité', 'dimanchea', 'cents', 'démocrate', 'sondage']
# Cluster 2 words:
# ['yakari', 'derib', 'pétasse', 'series', '25e', 'tomi']
# Cluster 3 words:
# ['septante', 'gouvernementale', 'peut', 'politiste', 'suissea', 'fédérales']
#
# 1999021-1999022:
# Cluster 0 words:
# ['chinoisea', 'présidente', 'manifestement', 'zemin', 'jiang', 'questionne']
# Cluster 1 words:
# ['yello', 'aimerais', 'techno', 'cétait', 'meyer', 'anné']
# Cluster 2 words:
# ['magique', 'lanternes', 'conceptions', 'neuch', 'philippine', 'enfantement']
#
# 1999019-1999021:
# Cluster 0 words:
# ['lanternes', 'magique', 'conceptions', 'enfantement', 'clubs', 'neuch']
# Cluster 1 words:
# ['chinoisea', 'partiez', 'présidente', 'manifestement', 'jiang', 'zemin']
# Cluster 2 words:
# ['genèvea', 'telecoms', 'organisez', 'faires', 'politiste', 'professionnelle']
# Cluster 3 words:
# ['téléphoniques', 'secteur', 'télécom', 'plusa', 'cétait', 'mutations']
# Cluster 4 words:
# ['cézanne', 'muses', 'matira', 'picasso', 'braques', 'rothko']
#
# 1999018-1999019:
# Cluster 0 words:
# ['maurane', 'boute', 'disque', 'blu', 'assume', 'vieux']
# Cluster 1 words:
# ['plusa', 'secteur', 'télécom', 'mutations', 'industre', 'téléphoniques']
# Cluster 2 words:
# ['genèvea', 'telecoms', 'organisez', 'suissea', 'faires', 'politiste']
# Cluster 3 words:
# ['êtres', 'mobiles', 'wapa', 'direction', 'connectez', 'appliqués']
# Cluster 4 words:
# ['cézanne', 'muses', 'braques', 'picasso', 'matira', 'rothko']
#
# 1999017-1999018:
# Cluster 0 words:
# ['maurane', 'boute', 'légi', 'opulentes', 'servi', 'chansons']
# Cluster 1 words:
# ['eye', 'shut', 'wide', 'filmait', 'kubrick', 'voit']
#
# 1999012-1999017:
# Cluster 0 words:
# ['shut', 'wide', 'eye', 'kubrick', 'voit', 'filmait']
# Cluster 1 words:
# ['accordait', 'négociés', 'suissea', 'relatées', 'européenn', 'couchepin']
# Cluster 2 words:
# ['jeuxa', 'radicalités', 'valais', 'propaganda', 'sion', 'mêmes']
#
# 1999010-1999012:
# Cluster 0 words:
# ['accordait', 'négociés', 'suissea', 'relatées', 'devrais', 'couchepin']
# Cluster 1 words:
# ['jeuxa', 'propaganda', 'radicalités', 'sion', 'paye', 'valais']
# Cluster 2 words:
# ['dessinatrice', 'dernier', 'xii', 'vance', 'anné', 'finirent']
#
# 1999006-1999010:
# Cluster 0 words:
# ['bouchet', 'carnets', 'andréa', 'poèmes', 'dirais', 'fidélistes']
# Cluster 1 words:
# ['présidente', 'jiang', 'chinoisea', 'zemin', 'suissea', 'fédérales']
# Cluster 2 words:
# ['dessinatrice', 'dernier', 'xii', 'vance', 'certain', 'blueberry']
# Cluster 3 words:
# ['présidente', 'zemin', 'jiang', 'chinoisea', 'fédérales', 'suissea']
#
# 1998011-1999006:
# Cluster 0 words:
# ['mêmes', 'carnets', 'bouchet', 'teller', 'fidélistes', 'travers']
# Cluster 1 words:
# ['banque', 'mathais', 'fusions', 'cabiallavetta', 'bilanz', 'journal']
# Cluster 2 words:
# ['présidente', 'jiang', 'chinoisea', 'zemin', 'fédérales', 'dreifuss']
# Cluster 3 words:
# ['banque', 'mathais', 'cabiallavetta', 'fusions', 'bilanz', 'journal']
# Cluster 4 words:
# ['présidente', 'jiang', 'chinoisea', 'zemin', 'fédérales', 'officiels']
#
# 1998009-1998011:
# Cluster 0 words:
# ['journal', 'cabiallavetta', 'bilanz', 'mathais', 'suissea', 'banque']
# Cluster 1 words:
# ['bancaire', 'nouvelle', 'banque', 'créditée', 'commission', 'concurrence']
# Cluster 2 words:
# ['religieuse', 'israéliens', 'isra', 'manifestement', 'internationaux', 'cétait']
# Cluster 3 words:
# ['cabiallavetta', 'bilanz', 'mathais', 'journal', 'banque', 'suissea']
# Cluster 4 words:
# ['bancaire', 'nouvelle', 'banque', 'créditée', 'commission', 'concurrence']
#
# 1998008-1998009:
# Cluster 0 words:
# ['banque', 'nouvelle', 'bancaire', 'créditée', 'danait', 'commission']
# Cluster 1 words:
# ['etat', 'fiscalea', 'secretive', 'bancaire', 'suissea', 'unis']
# Cluster 2 words:
# ['danait', 'religieuse', 'israéliens', 'isra', 'manifestement', 'internationaux']
# Cluster 3 words:
# ['banque', 'nouvelle', 'bancaire', 'créditée', 'danait', 'commission']
#
# 1970001-1998008:
# Cluster 0 words:
# ['etat', 'suissea', 'bancaire', 'fiscalea', 'secretive', 'financier']
# Cluster 1 words:
# ['danait', 'évacuaient', 'allemagne', 'habitera', 'opérants', 'plusieur']

# %% [markdown]
# ** Upload the results  as a dictionnary to MongoDB **

# %%
db_corpus.topicAnalysis.insert_one(
    {
        "id": "resultDict2",
        "topics": result_dict,
        "description": "List of list of words for each tuple biMonth"
    }
)
